# %% [markdown]
# <h1> Practical 3 - Language Modeling <h1>

# %% [markdown]
# After we have concerned ourselves with word embeddings and text classification in the previous notebooks, we will now focus on language modeling. </br>
#
# In the last practical we worked on text classification as a problem that could be solved with deep learning. Today, we will get to know a different application of RNN's, namely language modeling. </br>
#
# Word prediction is a Natural Language Processing - NLP application concerned with predicting the next word given the preceding text. Auto-complete or suggested responses are popular types of language prediction. The first step towards language prediction is the selection of a language model. </br>
#
# There are generally two models you can use to develop Next Word Predictor:
# </br> 1) statistical N-gram model or
# </br> 2) Neural Models

# %% [markdown]
# **0. Task (0 points)**  </br>
# As usual, before we dive into the tasks here are a couple imports we will later use

# %%
# !pip install boltons -q
# Out:
#      |████████████████████████████████| 174kB 8.2MB/s

# %%
import string
from pathlib import Path
from textwrap import wrap


import numpy as np
import pandas as pd
from boltons.iterutils import windowed
#from tqdm import tqdm_notebook
#from tqdm import tqdm
from tqdm.notebook import tqdm

from nltk.util import ngrams

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import optim
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.dataset import random_split
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence

from google_drive_downloader import GoogleDriveDownloader as gdd

from nltk.tokenize import sent_tokenize, word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
device_word = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device_char = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device_word
# Out:
# device(type='cuda')

# %% [markdown]
# <h1>Word and Text Generation</h1>
#
# In this notebook we will do two things:
# 1.   Generate a RNN, that can Learn how english characters are combined.
# 2.   Generate a RNN, that can Learn how english words are combined.
#
# Therefore we are going to do the following steps:
# 1.   Load the Data
# 2.   Preprocess the Data for character-level generation.
# 3.   Preprocess the Data for word-level generation.
# 4.   Building an RNN
# 5.   Applying the RNN on the Data of Step 1.
# 6.   Applying the RNN on the Data of Step 2.

# %% [markdown]
# <h2>1. Load the Data</h2>
#
# Our Dataset consists of multiple texts regarding weight loss.

# %%
#We can find the articles here:
DATA_PATH = 'data/weight_loss/articles.jsonl'
if not Path(DATA_PATH).is_file():
    gdd.download_file_from_google_drive(
        file_id='1mafPreWzE-FyLI0K-MUsXPcnUI0epIcI',
        dest_path='data/weight_loss/weight_loss_articles.zip',
        unzip=True,
    )
# Out:
# Downloading 1mafPreWzE-FyLI0K-MUsXPcnUI0epIcI into data/weight_loss/weight_loss_articles.zip... Done.
# Unzipping...Done.

# %%
#lets print out the first article
print(pd.read_json(DATA_PATH).text.str.lower().tolist()[0])
# Out:
# weight gaining is a common problem around the world. in developed country, it is the most common problem. in this article, i am not going to show you some advance and magical technique which will make you slim overnight. i am going to show you tips on the basis of real facts which works. in this article, i will give you how to tips, which will help you to lose weight. are you ready?
# calories requirement
# first thing you need to understand is why you gain weight. why? whenever you eat or drink something, you will get some calories. when you think about weight, everything revolves around calories.
# whatever you do, will burn some calories no matter how small work it is or just a movement of your body. your body burns thousands of calories in one day.
# if you are getting more calories than needed, you will gain weight. if you are getting fewer calories than needed, you will lose weight. so for losing weight, you need to know how much calorie your body required.
# find require calories for your body
# how will you know that how much calories your body require? well, there is a formula to find out that but you don't need to understand that. just go tohttp://www.freedieting.com/tools/calorie_calculator.htm. enter the details and you will come to know how much calories require for your body.
# now you know how much calories your body needs. you just need to balance between require and burning calories. there are two ways you can lose weight.
# you are not going to use only one. you will use mix of both. you will consume less calories and burn more calories. so keep a track of how much calories you take. also do some more exercise. not too much just a little more. so you burn more calories.
# you are controlling calories in two ways. losing little more calories and getting little less calories. so you will definitely lose weight.
# take less calories
# burn more calories

# %% [markdown]
# <h2>2. Preprocessing the data for sequence generation</h2>
#
# As you can see in the cell above it is pretty tedious to access the data. In the next few steps we help you and the network to access the data easier.

# %%
def remove_unprintable_chars(all_chars_windowed):
  not_printbl_chars=[]
  filtered_chars=[]
  printbl=True
  for sequence in tqdm(all_chars_windowed):
    printbl=True
    for char in sequence:
      if not(char in string.printable):
        printbl=False
        not_printbl_chars+=[char]
    if printbl==True:
      filtered_chars+=[sequence]
  return filtered_chars

# %%
def textlist_generator(path):
  return pd.read_json(path).text.str.lower().tolist()

# %%
texts = textlist_generator(DATA_PATH)
print('texts:', texts[0])
# Out:
# texts: weight gaining is a common problem around the world. in developed country, it is the most common problem. in this article, i am not going to show you some advance and magical technique which will make you slim overnight. i am going to show you tips on the basis of real facts which works. in this article, i will give you how to tips, which will help you to lose weight. are you ready?
# calories requirement
# first thing you need to understand is why you gain weight. why? whenever you eat or drink something, you will get some calories. when you think about weight, everything revolves around calories.
# whatever you do, will burn some calories no matter how small work it is or just a movement of your body. your body burns thousands of calories in one day.
# if you are getting more calories than needed, you will gain weight. if you are getting fewer calories than needed, you will lose weight. so for losing weight, you need to know how much calorie your body required.
# find require calories for your body
# how will you know that how much calories your body require? well, there is a formula to find out that but you don't need to understand that. just go tohttp://www.freedieting.com/tools/calorie_calculator.htm. enter the details and you will come to know how much calories require for your body.
# now you know how much calories your body needs. you just need to balance between require and burning calories. there are two ways you can lose weight.
# you are not going to use only one. you will use mix of both. you will consume less calories and burn more calories. so keep a track of how much calories you take. also do some more exercise. not too much just a little more. so you burn more calories.
# you are controlling calories in two ways. losing little more calories and getting little less calories. so you will definitely lose weight.
# take less calories
# burn more calories

# %%
def load_data_char(path, sequence_length=20):

    # Generate a list of texts from the dataset"
    texts = textlist_generator(path)
    print('texts:', texts[0])


    chars_windowed = [list(windowed(text, sequence_length)) for text in texts]
    print('chars_windowed:',chars_windowed[:2])
    
    
    all_chars_windowed = [sublst for lst in chars_windowed for sublst in lst]
    print('all chars windowed:', all_chars_windowed[:2])


    filtered_chars = remove_unprintable_chars(all_chars_windowed)
    #print('filtered_chars:', filtered_chars[:2])
    return filtered_chars

# %%
load_data_char(DATA_PATH)
# Out:
# texts: weight gaining is a common problem around the world. in developed country, it is the most common problem. in this article, i am not going to show you some advance and magical technique which will make you slim overnight. i am going to show you tips on the basis of real facts which works. in this article, i will give you how to tips, which will help you to lose weight. are you ready?
# calories requirement
# first thing you need to understand is why you gain weight. why? whenever you eat or drink something, you will get some calories. when you think about weight, everything revolves around calories.
# whatever you do, will burn some calories no matter how small work it is or just a movement of your body. your body burns thousands of calories in one day.
# if you are getting more calories than needed, you will gain weight. if you are getting fewer calories than needed, you will lose weight. so for losing weight, you need to know how much calorie your body required.
# find require calories for your body
# how will you know that how much calories your body require? well, there is a formula to find out that but you don't need to understand that. just go tohttp://www.freedieting.com/tools/calorie_calculator.htm. enter the details and you will come to know how much calories require for your body.
# now you know how much calories your body needs. you just need to balance between require and burning calories. there are two ways you can lose weight.
# you are not going to use only one. you will use mix of both. you will consume less calories and burn more calories. so keep a track of how much calories you take. also do some more exercise. not too much just a little more. so you burn more calories.
# you are controlling calories in two ways. losing little more calories and getting little less calories. so you will definitely lose weight.
# take less calories
# burn more calories
# chars_windowed: [[('w', 'e', 'i', 'g', 'h', 't', ' ', 'g', 'a', 'i'), ('e', 'i', 'g', 'h', 't', ' ', 'g', 'a', 'i', 'n'), ('i', 'g', 'h', 't', ' ', 'g', 'a', 'i', 'n', 'i'), ('g', 'h', 't', ' ', 'g', 'a', 'i', 'n', 'i', 'n'), ('h', 't', ' ', 'g', 'a', 'i', 'n', 'i', 'n', 'g'), ('t', ' ', 'g', 'a', 'i', 'n', 'i', 'n', 'g', ' '), (' ', 'g', 'a', 'i', 'n', 'i', 'n', 'g', ' ', 'i'), ('g', 'a', 'i', 'n', 'i', 'n', 'g', ' ', 'i', 's'), ('a', 'i', 'n', 'i', 'n', 'g', ' ', 'i', 's', ' '), ('i', 'n', 'i', 'n', 'g', ' ', 'i', 's', ' ', 'a'), ('n', 'i', 'n', 'g', ' ', 'i', 's', ' ', 'a', ' '), ('i', 'n', 'g', ' ', 'i', 's', ' ', 'a', ' ', 'c'), ('n', 'g', ' ', 'i', 's', ' ', 'a', ' ', 'c', 'o'), ('g', ' ', 'i', 's', ' ', 'a', ' ', 'c', 'o', 'm'), (' ', 'i', 's', ' ', 'a', ' ', 'c', 'o', 'm', 'm'), ('i', 's', ' ', 'a', ' ', 'c', 'o', 'm', 'm', 'o'), ('s', ' ', 'a', ' ', 'c', 'o', 'm', 'm', 'o', 'n'), (' ', 'a', ' ', 'c', 'o', 'm', 'm', 'o', 'n', ' '), ('a', ' ', 'c', 'o', 'm', 'm', 'o', 'n', ' ', 'p'), (' ', 'c', 'o', 'm', 'm', 'o', 'n', ' ', 'p', 'r'), ('c', 'o', 'm', 'm', 'o', 'n', ' ', 'p', 'r', 'o'), ('o', 'm', 'm', 'o', 'n', ' ', 'p', 'r', 'o', 'b'), ('m', 'm', 'o', 'n', ' ', 'p', 'r', 'o', 'b', 'l'), ('m', 'o', 'n', ' ', 'p', 'r', 'o', 'b', 'l', 'e'), ('o', 'n', ' ', 'p', 'r', 'o', 'b', 'l', 'e', 'm'), ('n', ' ', 'p', 'r', 'o', 'b', 'l', 'e', 'm', ' '), (' ', 'p', 'r', 'o', 'b', 'l', 'e', 'm', ' ', 'a'), ('p', 'r', 'o', 'b', 'l', 'e', 'm', ' ', 'a', 'r'), ('r', 'o', 'b', 'l', 'e', 'm', ' ', 'a', 'r', 'o'), ('o', 'b', 'l', 'e', 'm', ' ', 'a', 'r', 'o', 'u'), ('b', 'l', 'e', 'm', ' ', 'a', 'r', 'o', 'u', 'n'), ('l', 'e', 'm', ' ', 'a', 'r', 'o', 'u', 'n', 'd'), ('e', 'm', ' ', 'a', 'r', 'o', 'u', 'n', 'd', ' '), ('m', ' ', 'a', 'r', 'o', 'u', 'n', 'd', ' ', 't'), (' ', 'a', 'r', 'o', 'u', 'n', 'd
# all chars windowed: [('w', 'e', 'i', 'g', 'h', 't', ' ', 'g', 'a', 'i'), ('e', 'i', 'g', 'h', 't', ' ', 'g', 'a', 'i', 'n')]
# HBox(children=(FloatProgress(value=0.0, max=1305263.0), HTML(value='')))
# [('w', 'e', 'i', 'g', 'h', 't', ' ', 'g', 'a', 'i'),
#  ('e', 'i', 'g', 'h', 't', ' ', 'g', 'a', 'i', 'n'),
#  ('i', 'g', 'h', 't', ' ', 'g', 'a', 'i', 'n', 'i'),
#  ('g', 'h', 't', ' ', 'g', 'a', 'i', 'n', 'i', 'n'),
#  ('h', 't', ' ', 'g', 'a', 'i', 'n', 'i', 'n', 'g'),
#  ('t', ' ', 'g', 'a', 'i', 'n', 'i', 'n', 'g', ' '),
#  (' ', 'g', 'a', 'i', 'n', 'i', 'n', 'g', ' ', 'i'),
#  ('g', 'a', 'i', 'n', 'i', 'n', 'g', ' ', 'i', 's'),
#  ('a', 'i', 'n', 'i', 'n', 'g', ' ', 'i', 's', ' '),
#  ('i', 'n', 'i', 'n', 'g', ' ', 'i', 's', ' ', 'a'),
#  ('n', 'i', 'n', 'g', ' ', 'i', 's', ' ', 'a', ' '),
#  ('i', 'n', 'g', ' ', 'i', 's', ' ', 'a', ' ', 'c'),
#  ('n', 'g', ' ', 'i', 's', ' ', 'a', ' ', 'c', 'o'),
#  ('g', ' ', 'i', 's', ' ', 'a', ' ', 'c', 'o', 'm'),
#  (' ', 'i', 's', ' ', 'a', ' ', 'c', 'o', 'm', 'm'),
#  ('i', 's', ' ', 'a', ' ', 'c', 'o', 'm', 'm', 'o'),
#  ('s', ' ', 'a', ' ', 'c', 'o', 'm', 'm', 'o', 'n'),
#  (' ', 'a', ' ', 'c', 'o', 'm', 'm', 'o', 'n', ' '),
#  ('a', ' ', 'c', 'o', 'm', 'm', 'o', 'n', ' ', 'p'),
#  (' ', 'c', 'o', 'm', 'm', 'o', 'n', ' ', 'p', 'r'),
#  ('c', 'o', 'm', 'm', 'o', 'n', ' ', 'p', 'r', 'o'),
#  ('o', 'm', 'm', 'o', 'n', ' ', 'p', 'r', 'o', 'b'),
#  ('m', 'm', 'o', 'n', ' ', 'p', 'r', 'o', 'b', 'l'),
#  ('m', 'o', 'n', ' ', 'p', 'r', 'o', 'b', 'l', 'e'),
#  ('o', 'n', ' ', 'p', 'r', 'o', 'b', 'l', 'e', 'm'),
#  ('n', ' ', 'p', 'r', 'o', 'b', 'l', 'e', 'm', ' '),
#  (' ', 'p', 'r', 'o', 'b', 'l', 'e', 'm', ' ', 'a'),
#  ('p', 'r', 'o', 'b', 'l', 'e', 'm', ' ', 'a', 'r'),
#  ('r', 'o', 'b', 'l', 'e', 'm', ' ', 'a', 'r', 'o'),
#  ('o', 'b', 'l', 'e', 'm', ' ', 'a', 'r', 'o', 'u'),
#  ('b', 'l', 'e', 'm', ' ', 'a', 'r', 'o', 'u', 'n'),
#  ('l', 'e', 'm', ' ', 'a', 'r', 'o', 'u', 'n', 'd'),
#  ('e', 'm', ' ', 'a', 'r', 'o', 'u', 'n', 'd', ' '),
#  ('m', ' ', 'a', 'r', 'o', 'u', 'n', 'd', ' ', 't'),
#  (' ', 'a', 'r', 'o', 'u', 'n', 'd', ' ', 't', 'h'),
#  ('a', 'r', 'o', 'u', 'n', 'd', ' ', 't', 'h', 'e'),
#  ('r', 'o', 'u', 'n', 'd', ' ', 't', 'h', 'e', ' '),
#  ('o', 'u', 'n', 'd', ' ', 't', 'h', 'e', ' ', 'w'),
#  ('u', 'n', 'd', ' ', 't', 'h', 'e', ' ', 'w', 'o'),
#  ('n', 'd', ' ', 't', 'h', 'e', ' ', 'w', 'o', 'r'),
#  ('d', ' ', 't', 'h', 'e', ' ', 'w', 'o', 'r', 'l'),
#  (' ', 't', 'h', 'e', ' ', 'w', 'o', 'r', 'l', 'd'),
#  ('t', 'h', 'e', ' ', 'w', 'o', 'r', 'l', 'd', '.'),
#  ('h', 'e', ' ', 'w', 'o', 'r', 'l', 'd', '.', ' '),
#  ('e', ' ', 'w', 'o', 'r', 'l', 'd', '.', ' ', 'i'),
#  (' ', 'w', 'o', 'r', 'l', 'd', '.', ' ', 'i', 'n'),
#  ('w', 'o', 'r', 'l', 'd', '.', ' ', 'i', 'n', ' '),
#  ('o', 'r', 'l', 'd', '.', ' ', 'i', 'n', ' ', 'd'),
#  ('r', 'l', 'd', '.', ' ', 'i', 'n', ' ', 'd', 'e'),
#  ('l', 'd', '.', ' ', 'i', 'n', ' ', 'd', 'e', 'v'),
#  ('d', '.', ' ', 'i', 'n', ' ', 'd', 'e', 'v', 'e'),
#  ('.', ' ', 'i', 'n', ' ', 'd', 'e', 'v', 'e', 'l'),
#  (' ', 'i', 'n', ' ', 'd', 'e', 'v', 'e', 'l', 'o'),
#  ('i', 'n', ' ', 'd', 'e', 'v', 'e', 'l', 'o', 'p'),
#  ('n', ' ', 'd', 'e', 'v', 'e', 'l', 'o', 'p', 'e'),
#  (' ', 'd', 'e', 'v', 'e', 'l', 'o', 'p', 'e', 'd'),
#  ('d', 'e', 'v', 'e', 'l', 'o', 'p', 'e', 'd', ' '),
#  ('e', 'v', 'e', 'l', 'o', 'p', 'e', 'd', ' ', 'c'),
#  ('v', 'e', 'l', 'o', 'p', 'e', 'd', ' ', 'c', 'o'),
#  ('e', 'l', 'o', 'p', 'e', 'd', ' ', 'c', 'o', 'u'),
#  ('l', 'o', 'p', 'e', 'd', ' ', 'c', 'o', 'u', 'n'),
#  ('o', 'p', 'e', 'd', ' ', 'c', 'o', 'u', 'n', 't'),
#  ('p', 'e', 'd', ' ', 'c', 'o', 'u', 'n', 't', 'r'),
#  ('e', 'd', ' ', 'c', 'o', 'u', 'n', 't', 'r', 'y'),
#  ('d', ' ', 'c', 'o', 'u', 'n', 't', 'r', 'y', ','),
#  (' ', 'c', 'o', 'u', 'n', 't', 'r', 'y', ',', ' '),
#  ('c', 'o', 'u', 'n', 't', 'r', 'y', ',', ' ', 'i'),
#  ('o', 'u', 'n', 't', 'r', 'y', ',', ' ', 'i', 't'),
#  ('u', 'n', 't', 'r', 'y', ',', ' ', 'i', 't', ' '),
#  ('n', 't', 'r', 'y', ',', ' ', 'i', 't', ' ', 'i'),
#  ('t', 'r', 'y', ',', ' ', 'i', 't', ' ', 'i', 's'),
#  ('r', 'y', ',', ' ', 'i', 't', ' ', 'i', 's', ' '),
#  ('y', ',', ' ', 'i', 't', ' ', 'i', 's', ' ', 't'),
#  (',', ' ', 'i', 't', ' ', 'i', 's', ' ', 't', 'h'),
#  (' ', 'i', 't', ' ', 'i', 's', ' ', 't', 'h', 'e'),
#  ('i', 't', ' ', 'i', 's', ' ', 't', 'h', 'e', ' '),
#  ('t', ' ', 'i', 's', ' ', 't', 'h', 'e', ' ', 'm'),
#  (' ', 'i', 's', ' ', 't', 'h', 'e', ' ', 'm', 'o'),
#  ('i', 's', ' ', 't', 'h', 'e', ' ', 'm', 'o', 's'),
#  ('s', ' ', 't', 'h', 'e', ' ', 'm', 'o', 's', 't'),
#  (' ', 't', 'h', 'e', ' ', 'm', 'o', 's', 't', ' '),
#  ('t', 'h', 'e', ' ', 'm', 'o', 's', 't', ' ', 'c'),
#  ('h', 'e', ' ', 'm', 'o', 's', 't', ' ', 'c', 'o'),
#  ('e', ' ', 'm', 'o', 's', 't', ' ', 'c', 'o', 'm'),
#  (' ', 'm', 'o', 's', 't', ' ', 'c', 'o', 'm', 'm'),
#  ('m', 'o', 's', 't', ' ', 'c', 'o', 'm', 'm', 'o'),
#  ('o', 's', 't', ' ', 'c', 'o', 'm', 'm', 'o', 'n'),
#  ('s', 't', ' ', 'c', 'o', 'm', 'm', 'o', 'n', ' '),
#  ('t', ' ', 'c', 'o', 'm', 'm', 'o', 'n', ' ', 'p'),
#  (' ', 'c', 'o', 'm', 'm', 'o', 'n', ' ', 'p', 'r'),
#  ('c', 'o', 'm', 'm', 'o', 'n', ' ', 'p', 'r', 'o'),
#  ('o', 'm', 'm', 'o', 'n', ' ', 'p', 'r', 'o', 'b'),
#  ('m', 'm', 'o', 'n', ' ', 'p', 'r', 'o', 'b', 'l'),
#  ('m', 'o', 'n', ' ', 'p', 'r', 'o', 'b', 'l', 'e'),
#  ('o', 'n', ' ', 'p', 'r', 'o', 'b', 'l', 'e', 'm'),
#  ('n', ' ', 'p', 'r', 'o', 'b', 'l', 'e', 'm', '.'),
#  (' ', 'p', 'r', 'o', 'b', 'l', 'e', 'm', '.', ' '),
#  ('p', 'r', 'o', 'b', 'l', 'e', 'm', '.', ' ', 'i'),
#  ('r', 'o', 'b', 'l', 'e', 'm', '.', ' ', 'i', 'n'),
#  ('o', 'b', 'l', 'e', 'm', '.', ' ', 'i', 'n', ' '),
#  ('b', 'l', 'e', 'm', '.', ' ', 'i', 'n', ' ', 't'),
#  ('l', 'e', 'm', '.', ' ', 'i', 'n', ' ', 't', 'h'),
#  ('e', 'm', '.', ' ', 'i', 'n', ' ', 't', 'h', 'i'),
#  ('m', '.', ' ', 'i', 'n', ' ', 't', 'h', 'i', 's'),
#  ('.', ' ', 'i', 'n', ' ', 't', 'h', 'i', 's', ' '),
#  (' ', 'i', 'n', ' ', 't', 'h', 'i', 's', ' ', 'a'),
#  ('i', 'n', ' ', 't', 'h', 'i', 's', ' ', 'a', 'r'),
#  ('n', ' ', 't', 'h', 'i', 's', ' ', 'a', 'r', 't'),
#  (' ', 't', 'h', 'i', 's', ' ', 'a', 'r', 't', 'i'),
#  ('t', 'h', 'i', 's', ' ', 'a', 'r', 't', 'i', 'c'),
#  ('h', 'i', 's', ' ', 'a', 'r', 't', 'i', 'c', 'l'),
#  ('i', 's', ' ', 'a', 'r', 't', 'i', 'c', 'l', 'e'),
#  ('s', ' ', 'a', 'r', 't', 'i', 'c', 'l', 'e', ','),
#  (' ', 'a', 'r', 't', 'i', 'c', 'l', 'e', ',', ' '),
#  ('a', 'r', 't', 'i', 'c', 'l', 'e', ',', ' ', 'i'),
#  ('r', 't', 'i', 'c', 'l', 'e', ',', ' ', 'i', ' '),
#  ('t', 'i', 'c', 'l', 'e', ',', ' ', 'i', ' ', 'a'),
#  ('i', 'c', 'l', 'e', ',', ' ', 'i', ' ', 'a', 'm'),
#  ('c', 'l', 'e', ',', ' ', 'i', ' ', 'a', 'm', ' '),
#  ('l', 'e', ',', ' ', 'i', ' ', 'a', 'm', ' ', 'n'),
#  ('e', ',', ' ', 'i', ' ', 'a', 'm', ' ', 'n', 'o'),
#  (',', ' ', 'i', ' ', 'a', 'm', ' ', 'n', 'o', 't'),
#  (' ', 'i', ' ', 'a', 'm', ' ', 'n', 'o', 't', ' '),
#  ('i', ' ', 'a', 'm', ' ', 'n', 'o', 't', ' ', 'g'),
#  (' ', 'a', 'm', ' ', 'n', 'o', 't', ' ', 'g', 'o'),
#  ('a', 'm', ' ', 'n', 'o', 't', ' ', 'g', 'o', 'i'),
#  ('m', ' ', 'n', 'o', 't', ' ', 'g', 'o', 'i', 'n'),
#  (' ', 'n', 'o', 't', ' ', 'g', 'o', 'i', 'n', 'g'),
#  ('n', 'o', 't', ' ', 'g', 'o', 'i', 'n', 'g', ' '),
#  ('o', 't', ' ', 'g', 'o', 'i', 'n', 'g', ' ', 't'),
#  ('t', ' ', 'g', 'o', 'i', 'n', 'g', ' ', 't', 'o'),
#  (' ', 'g', 'o', 'i', 'n', 'g', ' ', 't', 'o', ' '),
#  ('g', 'o', 'i', 'n', 'g', ' ', 't', 'o', ' ', 's'),
#  ('o', 'i', 'n', 'g', ' ', 't', 'o', ' ', 's', 'h'),
#  ('i', 'n', 'g', ' ', 't', 'o', ' ', 's', 'h', 'o'),
#  ('n', 'g', ' ', 't', 'o', ' ', 's', 'h', 'o', 'w'),
#  ('g', ' ', 't', 'o', ' ', 's', 'h', 'o', 'w', ' '),
#  (' ', 't', 'o', ' ', 's', 'h', 'o', 'w', ' ', 'y'),
#  ('t', 'o', ' ', 's', 'h', 'o', 'w', ' ', 'y', 'o'),
#  ('o', ' ', 's', 'h', 'o', 'w', ' ', 'y', 'o', 'u'),
#  (' ', 's', 'h', 'o', 'w', ' ', 'y', 'o', 'u', ' '),
#  ('s', 'h', 'o', 'w', ' ', 'y', 'o', 'u', ' ', 's'),
#  ('h', 'o', 'w', ' ', 'y', 'o', 'u', ' ', 's', 'o'),
#  ('o', 'w', ' ', 'y', 'o', 'u', ' ', 's', 'o', 'm'),
#  ('w', ' ', 'y', 'o', 'u', ' ', 's', 'o', 'm', 'e'),
#  (' ', 'y', 'o', 'u', ' ', 's', 'o', 'm', 'e', ' '),
#  ('y', 'o', 'u', ' ', 's', 'o', 'm', 'e', ' ', 'a'),
#  ('o', 'u', ' ', 's', 'o', 'm', 'e', ' ', 'a', 'd'),
#  ('u', ' ', 's', 'o', 'm', 'e', ' ', 'a', 'd', 'v'),
#  (' ', 's', 'o', 'm', 'e', ' ', 'a', 'd', 'v', 'a'),
#  ('s', 'o', 'm', 'e', ' ', 'a', 'd', 'v', 'a', 'n'),
#  ('o', 'm', 'e', ' ', 'a', 'd', 'v', 'a', 'n', 'c'),
#  ('m', 'e', ' ', 'a', 'd', 'v', 'a', 'n', 'c', 'e'),
#  ('e', ' ', 'a', 'd', 'v', 'a', 'n', 'c', 'e', ' '),
#  (' ', 'a', 'd', 'v', 'a', 'n', 'c', 'e', ' ', 'a'),
#  ('a', 'd', 'v', 'a', 'n', 'c', 'e', ' ', 'a', 'n'),
#  ('d', 'v', 'a', 'n', 'c', 'e', ' ', 'a', 'n', 'd'),
#  ('v', 'a', 'n', 'c', 'e', ' ', 'a', 'n', 'd', ' '),
#  ('a', 'n', 'c', 'e', ' ', 'a', 'n', 'd', ' ', 'm'),
#  ('n', 'c', 'e', ' ', 'a', 'n', 'd', ' ', 'm', 'a'),
#  ('c', 'e', ' ', 'a', 'n', 'd', ' ', 'm', 'a', 'g'),
#  ('e', ' ', 'a', 'n', 'd', ' ', 'm', 'a', 'g', 'i'),
#  (' ', 'a', 'n', 'd', ' ', 'm', 'a', 'g', 'i', 'c'),
#  ('a', 'n', 'd', ' ', 'm', 'a', 'g', 'i', 'c', 'a'),
#  ('n', 'd', ' ', 'm', 'a', 'g', 'i', 'c', 'a', 'l'),
#  ('d', ' ', 'm', 'a', 'g', 'i', 'c', 'a', 'l', ' '),
#  (' ', 'm', 'a', 'g', 'i', 'c', 'a', 'l', ' ', 't'),
#  ('m', 'a', 'g', 'i', 'c', 'a', 'l', ' ', 't', 'e'),
#  ('a', 'g', 'i', 'c', 'a', 'l', ' ', 't', 'e', 'c'),
#  ('g', 'i', 'c', 'a', 'l', ' ', 't', 'e', 'c', 'h'),
#  ('i', 'c', 'a', 'l', ' ', 't', 'e', 'c', 'h', 'n'),
#  ('c', 'a', 'l', ' ', 't', 'e', 'c', 'h', 'n', 'i'),
#  ('a', 'l', ' ', 't', 'e', 'c', 'h', 'n', 'i', 'q'),
#  ('l', ' ', 't', 'e', 'c', 'h', 'n', 'i', 'q', 'u'),
#  (' ', 't', 'e', 'c', 'h', 'n', 'i', 'q', 'u', 'e'),
#  ('t', 'e', 'c', 'h', 'n', 'i', 'q', 'u', 'e', ' '),
#  ('e', 'c', 'h', 'n', 'i', 'q', 'u', 'e', ' ', 'w'),
#  ('c', 'h', 'n', 'i', 'q', 'u', 'e', ' ', 'w', 'h'),
#  ('h', 'n', 'i', 'q', 'u', 'e', ' ', 'w', 'h', 'i'),
#  ('n', 'i', 'q', 'u', 'e', ' ', 'w', 'h', 'i', 'c'),
#  ('i', 'q', 'u', 'e', ' ', 'w', 'h', 'i', 'c', 'h'),
#  ('q', 'u', 'e', ' ', 'w', 'h', 'i', 'c', 'h', ' '),
#  ('u', 'e', ' ', 'w', 'h', 'i', 'c', 'h', ' ', 'w'),
#  ('e', ' ', 'w', 'h', 'i', 'c', 'h', ' ', 'w', 'i'),
#  (' ', 'w', 'h', 'i', 'c', 'h', ' ', 'w', 'i', 'l'),
#  ('w', 'h', 'i', 'c', 'h', ' ', 'w', 'i', 'l', 'l'),
#  ('h', 'i', 'c', 'h', ' ', 'w', 'i', 'l', 'l', ' '),
#  ('i', 'c', 'h', ' ', 'w', 'i', 'l', 'l', ' ', 'm'),
#  ('c', 'h', ' ', 'w', 'i', 'l', 'l', ' ', 'm', 'a'),
#  ('h', ' ', 'w', 'i', 'l', 'l', ' ', 'm', 'a', 'k'),
#  (' ', 'w', 'i', 'l', 'l', ' ', 'm', 'a', 'k', 'e'),
#  ('w', 'i', 'l', 'l', ' ', 'm', 'a', 'k', 'e', ' '),
#  ('i', 'l', 'l', ' ', 'm', 'a', 'k', 'e', ' ', 'y'),
#  ('l', 'l', ' ', 'm', 'a', 'k', 'e', ' ', 'y', 'o'),
#  ('l', ' ', 'm', 'a', 'k', 'e', ' ', 'y', 'o', 'u'),
#  (' ', 'm', 'a', 'k', 'e', ' ', 'y', 'o', 'u', ' '),
#  ('m', 'a', 'k', 'e', ' ', 'y', 'o', 'u', ' ', 's'),
#  ('a', 'k', 'e', ' ', 'y', 'o', 'u', ' ', 's', 'l'),
#  ('k', 'e', ' ', 'y', 'o', 'u', ' ', 's', 'l', 'i'),
#  ('e', ' ', 'y', 'o', 'u', ' ', 's', 'l', 'i', 'm'),
#  (' ', 'y', 'o', 'u', ' ', 's', 'l', 'i', 'm', ' '),
#  ('y', 'o', 'u', ' ', 's', 'l', 'i', 'm', ' ', 'o'),
#  ('o', 'u', ' ', 's', 'l', 'i', 'm', ' ', 'o', 'v'),
#  ('u', ' ', 's', 'l', 'i', 'm', ' ', 'o', 'v', 'e'),
#  (' ', 's', 'l', 'i', 'm', ' ', 'o', 'v', 'e', 'r'),
#  ('s', 'l', 'i', 'm', ' ', 'o', 'v', 'e', 'r', 'n'),
#  ('l', 'i', 'm', ' ', 'o', 'v', 'e', 'r', 'n', 'i'),
#  ('i', 'm', ' ', 'o', 'v', 'e', 'r', 'n', 'i', 'g'),
#  ('m', ' ', 'o', 'v', 'e', 'r', 'n', 'i', 'g', 'h'),
#  (' ', 'o', 'v', 'e', 'r', 'n', 'i', 'g', 'h', 't'),
#  ('o', 'v', 'e', 'r', 'n', 'i', 'g', 'h', 't', '.'),
#  ('v', 'e', 'r', 'n', 'i', 'g', 'h', 't', '.', ' '),
#  ('e', 'r', 'n', 'i', 'g', 'h', 't', '.', ' ', 'i'),
#  ('r', 'n', 'i', 'g', 'h', 't', '.', ' ', 'i', ' '),
#  ('n', 'i', 'g', 'h', 't', '.', ' ', 'i', ' ', 'a'),
#  ('i', 'g', 'h', 't', '.', ' ', 'i', ' ', 'a', 'm'),
#  ('g', 'h', 't', '.', ' ', 'i', ' ', 'a', 'm', ' '),
#  ('h', 't', '.', ' ', 'i', ' ', 'a', 'm', ' ', 'g'),
#  ('t', '.', ' ', 'i', ' ', 'a', 'm', ' ', 'g', 'o'),
#  ('.', ' ', 'i', ' ', 'a', 'm', ' ', 'g', 'o', 'i'),
#  (' ', 'i', ' ', 'a', 'm', ' ', 'g', 'o', 'i', 'n'),
#  ('i', ' ', 'a', 'm', ' ', 'g', 'o', 'i', 'n', 'g'),
#  (' ', 'a', 'm', ' ', 'g', 'o', 'i', 'n', 'g', ' '),
#  ('a', 'm', ' ', 'g', 'o', 'i', 'n', 'g', ' ', 't'),
#  ('m', ' ', 'g', 'o', 'i', 'n', 'g', ' ', 't', 'o'),
#  (' ', 'g', 'o', 'i', 'n', 'g', ' ', 't', 'o', ' '),
#  ('g', 'o', 'i', 'n', 'g', ' ', 't', 'o', ' ', 's'),
#  ('o', 'i', 'n', 'g', ' ', 't', 'o', ' ', 's', 'h'),
#  ('i', 'n', 'g', ' ', 't', 'o', ' ', 's', 'h', 'o'),
#  ('n', 'g', ' ', 't', 'o', ' ', 's', 'h', 'o', 'w'),
#  ('g', ' ', 't', 'o', ' ', 's', 'h', 'o', 'w', ' '),
#  (' ', 't', 'o', ' ', 's', 'h', 'o', 'w', ' ', 'y'),
#  ('t', 'o', ' ', 's', 'h', 'o', 'w', ' ', 'y', 'o'),
#  ('o', ' ', 's', 'h', 'o', 'w', ' ', 'y', 'o', 'u'),
#  (' ', 's', 'h', 'o', 'w', ' ', 'y', 'o', 'u', ' '),
#  ('s', 'h', 'o', 'w', ' ', 'y', 'o', 'u', ' ', 't'),
#  ('h', 'o', 'w', ' ', 'y', 'o', 'u', ' ', 't', 'i'),
#  ('o', 'w', ' ', 'y', 'o', 'u', ' ', 't', 'i', 'p'),
#  ('w', ' ', 'y', 'o', 'u', ' ', 't', 'i', 'p', 's'),
#  (' ', 'y', 'o', 'u', ' ', 't', 'i', 'p', 's', ' '),
#  ('y', 'o', 'u', ' ', 't', 'i', 'p', 's', ' ', 'o'),
#  ('o', 'u', ' ', 't', 'i', 'p', 's', ' ', 'o', 'n'),
#  ('u', ' ', 't', 'i', 'p', 's', ' ', 'o', 'n', ' '),
#  (' ', 't', 'i', 'p', 's', ' ', 'o', 'n', ' ', 't'),
#  ('t', 'i', 'p', 's', ' ', 'o', 'n', ' ', 't', 'h'),
#  ('i', 'p', 's', ' ', 'o', 'n', ' ', 't', 'h', 'e'),
#  ('p', 's', ' ', 'o', 'n', ' ', 't', 'h', 'e', ' '),
#  ('s', ' ', 'o', 'n', ' ', 't', 'h', 'e', ' ', 'b'),
#  (' ', 'o', 'n', ' ', 't', 'h', 'e', ' ', 'b', 'a'),
#  ('o', 'n', ' ', 't', 'h', 'e', ' ', 'b', 'a', 's'),
#  ('n', ' ', 't', 'h', 'e', ' ', 'b', 'a', 's', 'i'),
#  (' ', 't', 'h', 'e', ' ', 'b', 'a', 's', 'i', 's'),
#  ('t', 'h', 'e', ' ', 'b', 'a', 's', 'i', 's', ' '),
#  ('h', 'e', ' ', 'b', 'a', 's', 'i', 's', ' ', 'o'),
#  ('e', ' ', 'b', 'a', 's', 'i', 's', ' ', 'o', 'f'),
#  (' ', 'b', 'a', 's', 'i', 's', ' ', 'o', 'f', ' '),
#  ('b', 'a', 's', 'i', 's', ' ', 'o', 'f', ' ', 'r'),
#  ('a', 's', 'i', 's', ' ', 'o', 'f', ' ', 'r', 'e'),
#  ('s', 'i', 's', ' ', 'o', 'f', ' ', 'r', 'e', 'a'),
#  ('i', 's', ' ', 'o', 'f', ' ', 'r', 'e', 'a', 'l'),
#  ('s', ' ', 'o', 'f', ' ', 'r', 'e', 'a', 'l', ' '),
#  (' ', 'o', 'f', ' ', 'r', 'e', 'a', 'l', ' ', 'f'),
#  ('o', 'f', ' ', 'r', 'e', 'a', 'l', ' ', 'f', 'a'),
#  ('f', ' ', 'r', 'e', 'a', 'l', ' ', 'f', 'a', 'c'),
#  (' ', 'r', 'e', 'a', 'l', ' ', 'f', 'a', 'c', 't'),
#  ('r', 'e', 'a', 'l', ' ', 'f', 'a', 'c', 't', 's'),
#  ('e', 'a', 'l', ' ', 'f', 'a', 'c', 't', 's', ' '),
#  ('a', 'l', ' ', 'f', 'a', 'c', 't', 's', ' ', 'w'),
#  ('l', ' ', 'f', 'a', 'c', 't', 's', ' ', 'w', 'h'),
#  (' ', 'f', 'a', 'c', 't', 's', ' ', 'w', 'h', 'i'),
#  ('f', 'a', 'c', 't', 's', ' ', 'w', 'h', 'i', 'c'),
#  ('a', 'c', 't', 's', ' ', 'w', 'h', 'i', 'c', 'h'),
#  ('c', 't', 's', ' ', 'w', 'h', 'i', 'c', 'h', ' '),
#  ('t', 's', ' ', 'w', 'h', 'i', 'c', 'h', ' ', 'w'),
#  ('s', ' ', 'w', 'h', 'i', 'c', 'h', ' ', 'w', 'o'),
#  (' ', 'w', 'h', 'i', 'c', 'h', ' ', 'w', 'o', 'r'),
#  ('w', 'h', 'i', 'c', 'h', ' ', 'w', 'o', 'r', 'k'),
#  ('h', 'i', 'c', 'h', ' ', 'w', 'o', 'r', 'k', 's'),
#  ('i', 'c', 'h', ' ', 'w', 'o', 'r', 'k', 's', '.'),
#  ('c', 'h', ' ', 'w', 'o', 'r', 'k', 's', '.', ' '),
#  ('h', ' ', 'w', 'o', 'r', 'k', 's', '.', ' ', 'i'),
#  (' ', 'w', 'o', 'r', 'k', 's', '.', ' ', 'i', 'n'),
#  ('w', 'o', 'r', 'k', 's', '.', ' ', 'i', 'n', ' '),
#  ('o', 'r', 'k', 's', '.', ' ', 'i', 'n', ' ', 't'),
#  ('r', 'k', 's', '.', ' ', 'i', 'n', ' ', 't', 'h'),
#  ('k', 's', '.', ' ', 'i', 'n', ' ', 't', 'h', 'i'),
#  ('s', '.', ' ', 'i', 'n', ' ', 't', 'h', 'i', 's'),
#  ('.', ' ', 'i', 'n', ' ', 't', 'h', 'i', 's', ' '),
#  (' ', 'i', 'n', ' ', 't', 'h', 'i', 's', ' ', 'a'),
#  ('i', 'n', ' ', 't', 'h', 'i', 's', ' ', 'a', 'r'),
#  ('n', ' ', 't', 'h', 'i', 's', ' ', 'a', 'r', 't'),
#  (' ', 't', 'h', 'i', 's', ' ', 'a', 'r', 't', 'i'),
#  ('t', 'h', 'i', 's', ' ', 'a', 'r', 't', 'i', 'c'),
#  ('h', 'i', 's', ' ', 'a', 'r', 't', 'i', 'c', 'l'),
#  ('i', 's', ' ', 'a', 'r', 't', 'i', 'c', 'l', 'e'),
#  ('s', ' ', 'a', 'r', 't', 'i', 'c', 'l', 'e', ','),
#  (' ', 'a', 'r', 't', 'i', 'c', 'l', 'e', ',', ' '),
#  ('a', 'r', 't', 'i', 'c', 'l', 'e', ',', ' ', 'i'),
#  ('r', 't', 'i', 'c', 'l', 'e', ',', ' ', 'i', ' '),
#  ('t', 'i', 'c', 'l', 'e', ',', ' ', 'i', ' ', 'w'),
#  ('i', 'c', 'l', 'e', ',', ' ', 'i', ' ', 'w', 'i'),
#  ('c', 'l', 'e', ',', ' ', 'i', ' ', 'w', 'i', 'l'),
#  ('l', 'e', ',', ' ', 'i', ' ', 'w', 'i', 'l', 'l'),
#  ('e', ',', ' ', 'i', ' ', 'w', 'i', 'l', 'l', ' '),
#  (',', ' ', 'i', ' ', 'w', 'i', 'l', 'l', ' ', 'g'),
#  (' ', 'i', ' ', 'w', 'i', 'l', 'l', ' ', 'g', 'i'),
#  ('i', ' ', 'w', 'i', 'l', 'l', ' ', 'g', 'i', 'v'),
#  (' ', 'w', 'i', 'l', 'l', ' ', 'g', 'i', 'v', 'e'),
#  ('w', 'i', 'l', 'l', ' ', 'g', 'i', 'v', 'e', ' '),
#  ('i', 'l', 'l', ' ', 'g', 'i', 'v', 'e', ' ', 'y'),
#  ('l', 'l', ' ', 'g', 'i', 'v', 'e', ' ', 'y', 'o'),
#  ('l', ' ', 'g', 'i', 'v', 'e', ' ', 'y', 'o', 'u'),
#  (' ', 'g', 'i', 'v', 'e', ' ', 'y', 'o', 'u', ' '),
#  ('g', 'i', 'v', 'e', ' ', 'y', 'o', 'u', ' ', 'h'),
#  ('i', 'v', 'e', ' ', 'y', 'o', 'u', ' ', 'h', 'o'),
#  ('v', 'e', ' ', 'y', 'o', 'u', ' ', 'h', 'o', 'w'),
#  ('e', ' ', 'y', 'o', 'u', ' ', 'h', 'o', 'w', ' '),
#  (' ', 'y', 'o', 'u', ' ', 'h', 'o', 'w', ' ', 't'),
#  ('y', 'o', 'u', ' ', 'h', 'o', 'w', ' ', 't', 'o'),
#  ('o', 'u', ' ', 'h', 'o', 'w', ' ', 't', 'o', ' '),
#  ('u', ' ', 'h', 'o', 'w', ' ', 't', 'o', ' ', 't'),
#  (' ', 'h', 'o', 'w', ' ', 't', 'o', ' ', 't', 'i'),
#  ('h', 'o', 'w', ' ', 't', 'o', ' ', 't', 'i', 'p'),
#  ('o', 'w', ' ', 't', 'o', ' ', 't', 'i', 'p', 's'),
#  ('w', ' ', 't', 'o', ' ', 't', 'i', 'p', 's', ','),
#  (' ', 't', 'o', ' ', 't', 'i', 'p', 's', ',', ' '),
#  ('t', 'o', ' ', 't', 'i', 'p', 's', ',', ' ', 'w'),
#  ('o', ' ', 't', 'i', 'p', 's', ',', ' ', 'w', 'h'),
#  (' ', 't', 'i', 'p', 's', ',', ' ', 'w', 'h', 'i'),
#  ('t', 'i', 'p', 's', ',', ' ', 'w', 'h', 'i', 'c'),
#  ('i', 'p', 's', ',', ' ', 'w', 'h', 'i', 'c', 'h'),
#  ('p', 's', ',', ' ', 'w', 'h', 'i', 'c', 'h', ' '),
#  ('s', ',', ' ', 'w', 'h', 'i', 'c', 'h', ' ', 'w'),
#  (',', ' ', 'w', 'h', 'i', 'c', 'h', ' ', 'w', 'i'),
#  (' ', 'w', 'h', 'i', 'c', 'h', ' ', 'w', 'i', 'l'),
#  ('w', 'h', 'i', 'c', 'h', ' ', 'w', 'i', 'l', 'l'),
#  ('h', 'i', 'c', 'h', ' ', 'w', 'i', 'l', 'l', ' '),
#  ('i', 'c', 'h', ' ', 'w', 'i', 'l', 'l', ' ', 'h'),
#  ('c', 'h', ' ', 'w', 'i', 'l', 'l', ' ', 'h', 'e'),
#  ('h', ' ', 'w', 'i', 'l', 'l', ' ', 'h', 'e', 'l'),
#  (' ', 'w', 'i', 'l', 'l', ' ', 'h', 'e', 'l', 'p'),
#  ('w', 'i', 'l', 'l', ' ', 'h', 'e', 'l', 'p', ' '),
#  ('i', 'l', 'l', ' ', 'h', 'e', 'l', 'p', ' ', 'y'),
#  ('l', 'l', ' ', 'h', 'e', 'l', 'p', ' ', 'y', 'o'),
#  ('l', ' ', 'h', 'e', 'l', 'p', ' ', 'y', 'o', 'u'),
#  (' ', 'h', 'e', 'l', 'p', ' ', 'y', 'o', 'u', ' '),
#  ('h', 'e', 'l', 'p', ' ', 'y', 'o', 'u', ' ', 't'),
#  ('e', 'l', 'p', ' ', 'y', 'o', 'u', ' ', 't', 'o'),
#  ('l', 'p', ' ', 'y', 'o', 'u', ' ', 't', 'o', ' '),
#  ('p', ' ', 'y', 'o', 'u', ' ', 't', 'o', ' ', 'l'),
#  (' ', 'y', 'o', 'u', ' ', 't', 'o', ' ', 'l', 'o'),
#  ('y', 'o', 'u', ' ', 't', 'o', ' ', 'l', 'o', 's'),
#  ('o', 'u', ' ', 't', 'o', ' ', 'l', 'o', 's', 'e'),
#  ('u', ' ', 't', 'o', ' ', 'l', 'o', 's', 'e', ' '),
#  (' ', 't', 'o', ' ', 'l', 'o', 's', 'e', ' ', 'w'),
#  ('t', 'o', ' ', 'l', 'o', 's', 'e', ' ', 'w', 'e'),
#  ('o', ' ', 'l', 'o', 's', 'e', ' ', 'w', 'e', 'i'),
#  (' ', 'l', 'o', 's', 'e', ' ', 'w', 'e', 'i', 'g'),
#  ('l', 'o', 's', 'e', ' ', 'w', 'e', 'i', 'g', 'h'),
#  ('o', 's', 'e', ' ', 'w', 'e', 'i', 'g', 'h', 't'),
#  ('s', 'e', ' ', 'w', 'e', 'i', 'g', 'h', 't', '.'),
#  ('e', ' ', 'w', 'e', 'i', 'g', 'h', 't', '.', ' '),
#  (' ', 'w', 'e', 'i', 'g', 'h', 't', '.', ' ', 'a'),
#  ('w', 'e', 'i', 'g', 'h', 't', '.', ' ', 'a', 'r'),
#  ('e', 'i', 'g', 'h', 't', '.', ' ', 'a', 'r', 'e'),
#  ('i', 'g', 'h', 't', '.', ' ', 'a', 'r', 'e', ' '),
#  ('g', 'h', 't', '.', ' ', 'a', 'r', 'e', ' ', 'y'),
#  ('h', 't', '.', ' ', 'a', 'r', 'e', ' ', 'y', 'o'),
#  ('t', '.', ' ', 'a', 'r', 'e', ' ', 'y', 'o', 'u'),
#  ('.', ' ', 'a', 'r', 'e', ' ', 'y', 'o', 'u', ' '),
#  (' ', 'a', 'r', 'e', ' ', 'y', 'o', 'u', ' ', 'r'),
#  ('a', 'r', 'e', ' ', 'y', 'o', 'u', ' ', 'r', 'e'),
#  ('r', 'e', ' ', 'y', 'o', 'u', ' ', 'r', 'e', 'a'),
#  ('e', ' ', 'y', 'o', 'u', ' ', 'r', 'e', 'a', 'd'),
#  (' ', 'y', 'o', 'u', ' ', 'r', 'e', 'a', 'd', 'y'),
#  ('y', 'o', 'u', ' ', 'r', 'e', 'a', 'd', 'y', '?'),
#  ('o', 'u', ' ', 'r', 'e', 'a', 'd', 'y', '?', '\n'),
#  ('u', ' ', 'r', 'e', 'a', 'd', 'y', '?', '\n', 'c'),
#  (' ', 'r', 'e', 'a', 'd', 'y', '?', '\n', 'c', 'a'),
#  ('r', 'e', 'a', 'd', 'y', '?', '\n', 'c', 'a', 'l'),
#  ('e', 'a', 'd', 'y', '?', '\n', 'c', 'a', 'l', 'o'),
#  ('a', 'd', 'y', '?', '\n', 'c', 'a', 'l', 'o', 'r'),
#  ('d', 'y', '?', '\n', 'c', 'a', 'l', 'o', 'r', 'i'),
#  ('y', '?', '\n', 'c', 'a', 'l', 'o', 'r', 'i', 'e'),
#  ('?', '\n', 'c', 'a', 'l', 'o', 'r', 'i', 'e', 's'),
#  ('\n', 'c', 'a', 'l', 'o', 'r', 'i', 'e', 's', ' '),
#  ('c', 'a', 'l', 'o', 'r', 'i', 'e', 's', ' ', 'r'),
#  ('a', 'l', 'o', 'r', 'i', 'e', 's', ' ', 'r', 'e'),
#  ('l', 'o', 'r', 'i', 'e', 's', ' ', 'r', 'e', 'q'),
#  ('o', 'r', 'i', 'e', 's', ' ', 'r', 'e', 'q', 'u'),
#  ('r', 'i', 'e', 's', ' ', 'r', 'e', 'q', 'u', 'i'),
#  ('i', 'e', 's', ' ', 'r', 'e', 'q', 'u', 'i', 'r'),
#  ('e', 's', ' ', 'r', 'e', 'q', 'u', 'i', 'r', 'e'),
#  ('s', ' ', 'r', 'e', 'q', 'u', 'i', 'r', 'e', 'm'),
#  (' ', 'r', 'e', 'q', 'u', 'i', 'r', 'e', 'm', 'e'),
#  ('r', 'e', 'q', 'u', 'i', 'r', 'e', 'm', 'e', 'n'),
#  ('e', 'q', 'u', 'i', 'r', 'e', 'm', 'e', 'n', 't'),
#  ('q', 'u', 'i', 'r', 'e', 'm', 'e', 'n', 't', '\n'),
#  ('u', 'i', 'r', 'e', 'm', 'e', 'n', 't', '\n', 'f'),
#  ('i', 'r', 'e', 'm', 'e', 'n', 't', '\n', 'f', 'i'),
#  ('r', 'e', 'm', 'e', 'n', 't', '\n', 'f', 'i', 'r'),
#  ('e', 'm', 'e', 'n', 't', '\n', 'f', 'i', 'r', 's'),
#  ('m', 'e', 'n', 't', '\n', 'f', 'i', 'r', 's', 't'),
#  ('e', 'n', 't', '\n', 'f', 'i', 'r', 's', 't', ' '),
#  ('n', 't', '\n', 'f', 'i', 'r', 's', 't', ' ', 't'),
#  ('t', '\n', 'f', 'i', 'r', 's', 't', ' ', 't', 'h'),
#  ('\n', 'f', 'i', 'r', 's', 't', ' ', 't', 'h', 'i'),
#  ('f', 'i', 'r', 's', 't', ' ', 't', 'h', 'i', 'n'),
#  ('i', 'r', 's', 't', ' ', 't', 'h', 'i', 'n', 'g'),
#  ('r', 's', 't', ' ', 't', 'h', 'i', 'n', 'g', ' '),
#  ('s', 't', ' ', 't', 'h', 'i', 'n', 'g', ' ', 'y'),
#  ('t', ' ', 't', 'h', 'i', 'n', 'g', ' ', 'y', 'o'),
#  (' ', 't', 'h', 'i', 'n', 'g', ' ', 'y', 'o', 'u'),
#  ('t', 'h', 'i', 'n', 'g', ' ', 'y', 'o', 'u', ' '),
#  ('h', 'i', 'n', 'g', ' ', 'y', 'o', 'u', ' ', 'n'),
#  ('i', 'n', 'g', ' ', 'y', 'o', 'u', ' ', 'n', 'e'),
#  ('n', 'g', ' ', 'y', 'o', 'u', ' ', 'n', 'e', 'e'),
#  ('g', ' ', 'y', 'o', 'u', ' ', 'n', 'e', 'e', 'd'),
#  (' ', 'y', 'o', 'u', ' ', 'n', 'e', 'e', 'd', ' '),
#  ('y', 'o', 'u', ' ', 'n', 'e', 'e', 'd', ' ', 't'),
#  ('o', 'u', ' ', 'n', 'e', 'e', 'd', ' ', 't', 'o'),
#  ('u', ' ', 'n', 'e', 'e', 'd', ' ', 't', 'o', ' '),
#  (' ', 'n', 'e', 'e', 'd', ' ', 't', 'o', ' ', 'u'),
#  ('n', 'e', 'e', 'd', ' ', 't', 'o', ' ', 'u', 'n'),
#  ('e', 'e', 'd', ' ', 't', 'o', ' ', 'u', 'n', 'd'),
#  ('e', 'd', ' ', 't', 'o', ' ', 'u', 'n', 'd', 'e'),
#  ('d', ' ', 't', 'o', ' ', 'u', 'n', 'd', 'e', 'r'),
#  (' ', 't', 'o', ' ', 'u', 'n', 'd', 'e', 'r', 's'),
#  ('t', 'o', ' ', 'u', 'n', 'd', 'e', 'r', 's', 't'),
#  ('o', ' ', 'u', 'n', 'd', 'e', 'r', 's', 't', 'a'),
#  (' ', 'u', 'n', 'd', 'e', 'r', 's', 't', 'a', 'n'),
#  ('u', 'n', 'd', 'e', 'r', 's', 't', 'a', 'n', 'd'),
#  ('n', 'd', 'e', 'r', 's', 't', 'a', 'n', 'd', ' '),
#  ('d', 'e', 'r', 's', 't', 'a', 'n', 'd', ' ', 'i'),
#  ('e', 'r', 's', 't', 'a', 'n', 'd', ' ', 'i', 's'),
#  ('r', 's', 't', 'a', 'n', 'd', ' ', 'i', 's', ' '),
#  ('s', 't', 'a', 'n', 'd', ' ', 'i', 's', ' ', 'w'),
#  ('t', 'a', 'n', 'd', ' ', 'i', 's', ' ', 'w', 'h'),
#  ('a', 'n', 'd', ' ', 'i', 's', ' ', 'w', 'h', 'y'),
#  ('n', 'd', ' ', 'i', 's', ' ', 'w', 'h', 'y', ' '),
#  ('d', ' ', 'i', 's', ' ', 'w', 'h', 'y', ' ', 'y'),
#  (' ', 'i', 's', ' ', 'w', 'h', 'y', ' ', 'y', 'o'),
#  ('i', 's', ' ', 'w', 'h', 'y', ' ', 'y', 'o', 'u'),
#  ('s', ' ', 'w', 'h', 'y', ' ', 'y', 'o', 'u', ' '),
#  (' ', 'w', 'h', 'y', ' ', 'y', 'o', 'u', ' ', 'g'),
#  ('w', 'h', 'y', ' ', 'y', 'o', 'u', ' ', 'g', 'a'),
#  ('h', 'y', ' ', 'y', 'o', 'u', ' ', 'g', 'a', 'i'),
#  ('y', ' ', 'y', 'o', 'u', ' ', 'g', 'a', 'i', 'n'),
#  (' ', 'y', 'o', 'u', ' ', 'g', 'a', 'i', 'n', ' '),
#  ('y', 'o', 'u', ' ', 'g', 'a', 'i', 'n', ' ', 'w'),
#  ('o', 'u', ' ', 'g', 'a', 'i', 'n', ' ', 'w', 'e'),
#  ('u', ' ', 'g', 'a', 'i', 'n', ' ', 'w', 'e', 'i'),
#  (' ', 'g', 'a', 'i', 'n', ' ', 'w', 'e', 'i', 'g'),
#  ('g', 'a', 'i', 'n', ' ', 'w', 'e', 'i', 'g', 'h'),
#  ('a', 'i', 'n', ' ', 'w', 'e', 'i', 'g', 'h', 't'),
#  ('i', 'n', ' ', 'w', 'e', 'i', 'g', 'h', 't', '.'),
#  ('n', ' ', 'w', 'e', 'i', 'g', 'h', 't', '.', ' '),
#  (' ', 'w', 'e', 'i', 'g', 'h', 't', '.', ' ', 'w'),
#  ('w', 'e', 'i', 'g', 'h', 't', '.', ' ', 'w', 'h'),
#  ('e', 'i', 'g', 'h', 't', '.', ' ', 'w', 'h', 'y'),
#  ('i', 'g', 'h', 't', '.', ' ', 'w', 'h', 'y', '?'),
#  ('g', 'h', 't', '.', ' ', 'w', 'h', 'y', '?', ' '),
#  ('h', 't', '.', ' ', 'w', 'h', 'y', '?', ' ', 'w'),
#  ('t', '.', ' ', 'w', 'h', 'y', '?', ' ', 'w', 'h'),
#  ('.', ' ', 'w', 'h', 'y', '?', ' ', 'w', 'h', 'e'),
#  (' ', 'w', 'h', 'y', '?', ' ', 'w', 'h', 'e', 'n'),
#  ('w', 'h', 'y', '?', ' ', 'w', 'h', 'e', 'n', 'e'),
#  ('h', 'y', '?', ' ', 'w', 'h', 'e', 'n', 'e', 'v'),
#  ('y', '?', ' ', 'w', 'h', 'e', 'n', 'e', 'v', 'e'),
#  ('?', ' ', 'w', 'h', 'e', 'n', 'e', 'v', 'e', 'r'),
#  (' ', 'w', 'h', 'e', 'n', 'e', 'v', 'e', 'r', ' '),
#  ('w', 'h', 'e', 'n', 'e', 'v', 'e', 'r', ' ', 'y'),
#  ('h', 'e', 'n', 'e', 'v', 'e', 'r', ' ', 'y', 'o'),
#  ('e', 'n', 'e', 'v', 'e', 'r', ' ', 'y', 'o', 'u'),
#  ('n', 'e', 'v', 'e', 'r', ' ', 'y', 'o', 'u', ' '),
#  ('e', 'v', 'e', 'r', ' ', 'y', 'o', 'u', ' ', 'e'),
#  ('v', 'e', 'r', ' ', 'y', 'o', 'u', ' ', 'e', 'a'),
#  ('e', 'r', ' ', 'y', 'o', 'u', ' ', 'e', 'a', 't'),
#  ('r', ' ', 'y', 'o', 'u', ' ', 'e', 'a', 't', ' '),
#  (' ', 'y', 'o', 'u', ' ', 'e', 'a', 't', ' ', 'o'),
#  ('y', 'o', 'u', ' ', 'e', 'a', 't', ' ', 'o', 'r'),
#  ('o', 'u', ' ', 'e', 'a', 't', ' ', 'o', 'r', ' '),
#  ('u', ' ', 'e', 'a', 't', ' ', 'o', 'r', ' ', 'd'),
#  (' ', 'e', 'a', 't', ' ', 'o', 'r', ' ', 'd', 'r'),
#  ('e', 'a', 't', ' ', 'o', 'r', ' ', 'd', 'r', 'i'),
#  ('a', 't', ' ', 'o', 'r', ' ', 'd', 'r', 'i', 'n'),
#  ('t', ' ', 'o', 'r', ' ', 'd', 'r', 'i', 'n', 'k'),
#  (' ', 'o', 'r', ' ', 'd', 'r', 'i', 'n', 'k', ' '),
#  ('o', 'r', ' ', 'd', 'r', 'i', 'n', 'k', ' ', 's'),
#  ('r', ' ', 'd', 'r', 'i', 'n', 'k', ' ', 's', 'o'),
#  (' ', 'd', 'r', 'i', 'n', 'k', ' ', 's', 'o', 'm'),
#  ('d', 'r', 'i', 'n', 'k', ' ', 's', 'o', 'm', 'e'),
#  ('r', 'i', 'n', 'k', ' ', 's', 'o', 'm', 'e', 't'),
#  ('i', 'n', 'k', ' ', 's', 'o', 'm', 'e', 't', 'h'),
#  ('n', 'k', ' ', 's', 'o', 'm', 'e', 't', 'h', 'i'),
#  ('k', ' ', 's', 'o', 'm', 'e', 't', 'h', 'i', 'n'),
#  (' ', 's', 'o', 'm', 'e', 't', 'h', 'i', 'n', 'g'),
#  ('s', 'o', 'm', 'e', 't', 'h', 'i', 'n', 'g', ','),
#  ('o', 'm', 'e', 't', 'h', 'i', 'n', 'g', ',', ' '),
#  ('m', 'e', 't', 'h', 'i', 'n', 'g', ',', ' ', 'y'),
#  ('e', 't', 'h', 'i', 'n', 'g', ',', ' ', 'y', 'o'),
#  ('t', 'h', 'i', 'n', 'g', ',', ' ', 'y', 'o', 'u'),
#  ('h', 'i', 'n', 'g', ',', ' ', 'y', 'o', 'u', ' '),
#  ('i', 'n', 'g', ',', ' ', 'y', 'o', 'u', ' ', 'w'),
#  ('n', 'g', ',', ' ', 'y', 'o', 'u', ' ', 'w', 'i'),
#  ('g', ',', ' ', 'y', 'o', 'u', ' ', 'w', 'i', 'l'),
#  (',', ' ', 'y', 'o', 'u', ' ', 'w', 'i', 'l', 'l'),
#  (' ', 'y', 'o', 'u', ' ', 'w', 'i', 'l', 'l', ' '),
#  ('y', 'o', 'u', ' ', 'w', 'i', 'l', 'l', ' ', 'g'),
#  ('o', 'u', ' ', 'w', 'i', 'l', 'l', ' ', 'g', 'e'),
#  ('u', ' ', 'w', 'i', 'l', 'l', ' ', 'g', 'e', 't'),
#  (' ', 'w', 'i', 'l', 'l', ' ', 'g', 'e', 't', ' '),
#  ('w', 'i', 'l', 'l', ' ', 'g', 'e', 't', ' ', 's'),
#  ('i', 'l', 'l', ' ', 'g', 'e', 't', ' ', 's', 'o'),
#  ('l', 'l', ' ', 'g', 'e', 't', ' ', 's', 'o', 'm'),
#  ('l', ' ', 'g', 'e', 't', ' ', 's', 'o', 'm', 'e'),
#  (' ', 'g', 'e', 't', ' ', 's', 'o', 'm', 'e', ' '),
#  ('g', 'e', 't', ' ', 's', 'o', 'm', 'e', ' ', 'c'),
#  ('e', 't', ' ', 's', 'o', 'm', 'e', ' ', 'c', 'a'),
#  ('t', ' ', 's', 'o', 'm', 'e', ' ', 'c', 'a', 'l'),
#  (' ', 's', 'o', 'm', 'e', ' ', 'c', 'a', 'l', 'o'),
#  ('s', 'o', 'm', 'e', ' ', 'c', 'a', 'l', 'o', 'r'),
#  ('o', 'm', 'e', ' ', 'c', 'a', 'l', 'o', 'r', 'i'),
#  ('m', 'e', ' ', 'c', 'a', 'l', 'o', 'r', 'i', 'e'),
#  ('e', ' ', 'c', 'a', 'l', 'o', 'r', 'i', 'e', 's'),
#  (' ', 'c', 'a', 'l', 'o', 'r', 'i', 'e', 's', '.'),
#  ('c', 'a', 'l', 'o', 'r', 'i', 'e', 's', '.', ' '),
#  ('a', 'l', 'o', 'r', 'i', 'e', 's', '.', ' ', 'w'),
#  ('l', 'o', 'r', 'i', 'e', 's', '.', ' ', 'w', 'h'),
#  ('o', 'r', 'i', 'e', 's', '.', ' ', 'w', 'h', 'e'),
#  ('r', 'i', 'e', 's', '.', ' ', 'w', 'h', 'e', 'n'),
#  ('i', 'e', 's', '.', ' ', 'w', 'h', 'e', 'n', ' '),
#  ('e', 's', '.', ' ', 'w', 'h', 'e', 'n', ' ', 'y'),
#  ('s', '.', ' ', 'w', 'h', 'e', 'n', ' ', 'y', 'o'),
#  ('.', ' ', 'w', 'h', 'e', 'n', ' ', 'y', 'o', 'u'),
#  (' ', 'w', 'h', 'e', 'n', ' ', 'y', 'o', 'u', ' '),
#  ('w', 'h', 'e', 'n', ' ', 'y', 'o', 'u', ' ', 't'),
#  ('h', 'e', 'n', ' ', 'y', 'o', 'u', ' ', 't', 'h'),
#  ('e', 'n', ' ', 'y', 'o', 'u', ' ', 't', 'h', 'i'),
#  ('n', ' ', 'y', 'o', 'u', ' ', 't', 'h', 'i', 'n'),
#  (' ', 'y', 'o', 'u', ' ', 't', 'h', 'i', 'n', 'k'),
#  ('y', 'o', 'u', ' ', 't', 'h', 'i', 'n', 'k', ' '),
#  ('o', 'u', ' ', 't', 'h', 'i', 'n', 'k', ' ', 'a'),
#  ('u', ' ', 't', 'h', 'i', 'n', 'k', ' ', 'a', 'b'),
#  (' ', 't', 'h', 'i', 'n', 'k', ' ', 'a', 'b', 'o'),
#  ('t', 'h', 'i', 'n', 'k', ' ', 'a', 'b', 'o', 'u'),
#  ('h', 'i', 'n', 'k', ' ', 'a', 'b', 'o', 'u', 't'),
#  ('i', 'n', 'k', ' ', 'a', 'b', 'o', 'u', 't', ' '),
#  ('n', 'k', ' ', 'a', 'b', 'o', 'u', 't', ' ', 'w'),
#  ('k', ' ', 'a', 'b', 'o', 'u', 't', ' ', 'w', 'e'),
#  (' ', 'a', 'b', 'o', 'u', 't', ' ', 'w', 'e', 'i'),
#  ('a', 'b', 'o', 'u', 't', ' ', 'w', 'e', 'i', 'g'),
#  ('b', 'o', 'u', 't', ' ', 'w', 'e', 'i', 'g', 'h'),
#  ('o', 'u', 't', ' ', 'w', 'e', 'i', 'g', 'h', 't'),
#  ('u', 't', ' ', 'w', 'e', 'i', 'g', 'h', 't', ','),
#  ('t', ' ', 'w', 'e', 'i', 'g', 'h', 't', ',', ' '),
#  (' ', 'w', 'e', 'i', 'g', 'h', 't', ',', ' ', 'e'),
#  ('w', 'e', 'i', 'g', 'h', 't', ',', ' ', 'e', 'v'),
#  ('e', 'i', 'g', 'h', 't', ',', ' ', 'e', 'v', 'e'),
#  ('i', 'g', 'h', 't', ',', ' ', 'e', 'v', 'e', 'r'),
#  ('g', 'h', 't', ',', ' ', 'e', 'v', 'e', 'r', 'y'),
#  ('h', 't', ',', ' ', 'e', 'v', 'e', 'r', 'y', 't'),
#  ('t', ',', ' ', 'e', 'v', 'e', 'r', 'y', 't', 'h'),
#  (',', ' ', 'e', 'v', 'e', 'r', 'y', 't', 'h', 'i'),
#  (' ', 'e', 'v', 'e', 'r', 'y', 't', 'h', 'i', 'n'),
#  ('e', 'v', 'e', 'r', 'y', 't', 'h', 'i', 'n', 'g'),
#  ('v', 'e', 'r', 'y', 't', 'h', 'i', 'n', 'g', ' '),
#  ('e', 'r', 'y', 't', 'h', 'i', 'n', 'g', ' ', 'r'),
#  ('r', 'y', 't', 'h', 'i', 'n', 'g', ' ', 'r', 'e'),
#  ('y', 't', 'h', 'i', 'n', 'g', ' ', 'r', 'e', 'v'),
#  ('t', 'h', 'i', 'n', 'g', ' ', 'r', 'e', 'v', 'o'),
#  ('h', 'i', 'n', 'g', ' ', 'r', 'e', 'v', 'o', 'l'),
#  ('i', 'n', 'g', ' ', 'r', 'e', 'v', 'o', 'l', 'v'),
#  ('n', 'g', ' ', 'r', 'e', 'v', 'o', 'l', 'v', 'e'),
#  ('g', ' ', 'r', 'e', 'v', 'o', 'l', 'v', 'e', 's'),
#  (' ', 'r', 'e', 'v', 'o', 'l', 'v', 'e', 's', ' '),
#  ('r', 'e', 'v', 'o', 'l', 'v', 'e', 's', ' ', 'a'),
#  ('e', 'v', 'o', 'l', 'v', 'e', 's', ' ', 'a', 'r'),
#  ('v', 'o', 'l', 'v', 'e', 's', ' ', 'a', 'r', 'o'),
#  ('o', 'l', 'v', 'e', 's', ' ', 'a', 'r', 'o', 'u'),
#  ('l', 'v', 'e', 's', ' ', 'a', 'r', 'o', 'u', 'n'),
#  ('v', 'e', 's', ' ', 'a', 'r', 'o', 'u', 'n', 'd'),
#  ('e', 's', ' ', 'a', 'r', 'o', 'u', 'n', 'd', ' '),
#  ('s', ' ', 'a', 'r', 'o', 'u', 'n', 'd', ' ', 'c'),
#  (' ', 'a', 'r', 'o', 'u', 'n', 'd', ' ', 'c', 'a'),
#  ('a', 'r', 'o', 'u', 'n', 'd', ' ', 'c', 'a', 'l'),
#  ('r', 'o', 'u', 'n', 'd', ' ', 'c', 'a', 'l', 'o'),
#  ('o', 'u', 'n', 'd', ' ', 'c', 'a', 'l', 'o', 'r'),
#  ('u', 'n', 'd', ' ', 'c', 'a', 'l', 'o', 'r', 'i'),
#  ('n', 'd', ' ', 'c', 'a', 'l', 'o', 'r', 'i', 'e'),
#  ('d', ' ', 'c', 'a', 'l', 'o', 'r', 'i', 'e', 's'),
#  (' ', 'c', 'a', 'l', 'o', 'r', 'i', 'e', 's', '.'),
#  ('c', 'a', 'l', 'o', 'r', 'i', 'e', 's', '.', '\n'),
#  ('a', 'l', 'o', 'r', 'i', 'e', 's', '.', '\n', 'w'),
#  ('l', 'o', 'r', 'i', 'e', 's', '.', '\n', 'w', 'h'),
#  ('o', 'r', 'i', 'e', 's', '.', '\n', 'w', 'h', 'a'),
#  ('r', 'i', 'e', 's', '.', '\n', 'w', 'h', 'a', 't'),
#  ('i', 'e', 's', '.', '\n', 'w', 'h', 'a', 't', 'e'),
#  ('e', 's', '.', '\n', 'w', 'h', 'a', 't', 'e', 'v'),
#  ('s', '.', '\n', 'w', 'h', 'a', 't', 'e', 'v', 'e'),
#  ('.', '\n', 'w', 'h', 'a', 't', 'e', 'v', 'e', 'r'),
#  ('\n', 'w', 'h', 'a', 't', 'e', 'v', 'e', 'r', ' '),
#  ('w', 'h', 'a', 't', 'e', 'v', 'e', 'r', ' ', 'y'),
#  ('h', 'a', 't', 'e', 'v', 'e', 'r', ' ', 'y', 'o'),
#  ('a', 't', 'e', 'v', 'e', 'r', ' ', 'y', 'o', 'u'),
#  ('t', 'e', 'v', 'e', 'r', ' ', 'y', 'o', 'u', ' '),
#  ('e', 'v', 'e', 'r', ' ', 'y', 'o', 'u', ' ', 'd'),
#  ('v', 'e', 'r', ' ', 'y', 'o', 'u', ' ', 'd', 'o'),
#  ('t', 'e', 'r', ' ', 'h', 'o', 'w', ' ', 's', 'm'),
#  ('e', 'r', ' ', 'h', 'o', 'w', ' ', 's', 'm', 'a'),
#  ('r', ' ', 'h', 'o', 'w', ' ', 's', 'm', 'a', 'l'),
#  (' ', 'h', 'o', 'w', ' ', 's', 'm', 'a', 'l', 'l'),
#  ('h', 'o', 'w', ' ', 's', 'm', 'a', 'l', 'l', ' '),
#  ('o', 'w', ' ', 's', 'm', 'a', 'l', 'l', ' ', 'w'),
#  ('w', ' ', 's', 'm', 'a', 'l', 'l', ' ', 'w', 'o'),
#  (' ', 's', 'm', 'a', 'l', 'l', ' ', 'w', 'o', 'r'),
#  ('s', 'm', 'a', 'l', 'l', ' ', 'w', 'o', 'r', 'k'),
#  ('m', 'a', 'l', 'l', ' ', 'w', 'o', 'r', 'k', ' '),
#  ('a', 'l', 'l', ' ', 'w', 'o', 'r', 'k', ' ', 'i'),
#  ('l', 'l', ' ', 'w', 'o', 'r', 'k', ' ', 'i', 't'),
#  ('l', ' ', 'w', 'o', 'r', 'k', ' ', 'i', 't', ' '),
#  (' ', 'w', 'o', 'r', 'k', ' ', 'i', 't', ' ', 'i'),
#  ('w', 'o', 'r', 'k', ' ', 'i', 't', ' ', 'i', 's'),
#  ('o', 'r', 'k', ' ', 'i', 't', ' ', 'i', 's', ' '),
#  ('r', 'k', ' ', 'i', 't', ' ', 'i', 's', ' ', 'o'),
#  ('k', ' ', 'i', 't', ' ', 'i', 's', ' ', 'o', 'r'),
#  (' ', 'i', 't', ' ', 'i', 's', ' ', 'o', 'r', ' '),
#  ('i', 't', ' ', 'i', 's', ' ', 'o', 'r', ' ', 'j'),
#  ('t', ' ', 'i', 's', ' ', 'o', 'r', ' ', 'j', 'u'),
#  (' ', 'i', 's', ' ', 'o', 'r', ' ', 'j', 'u', 's'),
#  ('i', 's', ' ', 'o', 'r', ' ', 'j', 'u', 's', 't'),
#  ('s', ' ', 'o', 'r', ' ', 'j', 'u', 's', 't', ' '),
#  (' ', 'o', 'r', ' ', 'j', 'u', 's', 't', ' ', 'a'),
#  ('o', 'r', ' ', 'j', 'u', 's', 't', ' ', 'a', ' '),
#  ('r', ' ', 'j', 'u', 's', 't', ' ', 'a', ' ', 'm'),
#  (' ', 'j', 'u', 's', 't', ' ', 'a', ' ', 'm', 'o'),
#  ('j', 'u', 's', 't', ' ', 'a', ' ', 'm', 'o', 'v'),
#  ('u', 's', 't', ' ', 'a', ' ', 'm', 'o', 'v', 'e'),
#  ('s', 't', ' ', 'a', ' ', 'm', 'o', 'v', 'e', 'm'),
#  ('t', ' ', 'a', ' ', 'm', 'o', 'v', 'e', 'm', 'e'),
#  (' ', 'a', ' ', 'm', 'o', 'v', 'e', 'm', 'e', 'n'),
#  ('a', ' ', 'm', 'o', 'v', 'e', 'm', 'e', 'n', 't'),
#  (' ', 'm', 'o', 'v', 'e', 'm', 'e', 'n', 't', ' '),
#  ('m', 'o', 'v', 'e', 'm', 'e', 'n', 't', ' ', 'o'),
#  ('o', 'v', 'e', 'm', 'e', 'n', 't', ' ', 'o', 'f'),
#  ('v', 'e', 'm', 'e', 'n', 't', ' ', 'o', 'f', ' '),
#  ('e', 'm', 'e', 'n', 't', ' ', 'o', 'f', ' ', 'y'),
#  ('m', 'e', 'n', 't', ' ', 'o', 'f', ' ', 'y', 'o'),
#  ('e', 'n', 't', ' ', 'o', 'f', ' ', 'y', 'o', 'u'),
#  ('n', 't', ' ', 'o', 'f', ' ', 'y', 'o', 'u', 'r'),
#  ('t', ' ', 'o', 'f', ' ', 'y', 'o', 'u', 'r', ' '),
#  (' ', 'o', 'f', ' ', 'y', 'o', 'u', 'r', ' ', 'b'),
#  ('o', 'f', ' ', 'y', 'o', 'u', 'r', ' ', 'b', 'o'),
#  ('f', ' ', 'y', 'o', 'u', 'r', ' ', 'b', 'o', 'd'),
#  (' ', 'y', 'o', 'u', 'r', ' ', 'b', 'o', 'd', 'y'),
#  ('y', 'o', 'u', 'r', ' ', 'b', 'o', 'd', 'y', '.'),
#  ('o', 'u', 'r', ' ', 'b', 'o', 'd', 'y', '.', ' '),
#  ('u', 'r', ' ', 'b', 'o', 'd', 'y', '.', ' ', 'y'),
#  ('r', ' ', 'b', 'o', 'd', 'y', '.', ' ', 'y', 'o'),
#  (' ', 'b', 'o', 'd', 'y', '.', ' ', 'y', 'o', 'u'),
#  ('b', 'o', 'd', 'y', '.', ' ', 'y', 'o', 'u', 'r'),
#  ('o', 'd', 'y', '.', ' ', 'y', 'o', 'u', 'r', ' '),
#  ('d', 'y', '.', ' ', 'y', 'o', 'u', 'r', ' ', 'b'),
#  ('y', '.', ' ', 'y', 'o', 'u', 'r', ' ', 'b', 'o'),
#  ('.', ' ', 'y', 'o', 'u', 'r', ' ', 'b', 'o', 'd'),
#  (' ', 'y', 'o', 'u', 'r', ' ', 'b', 'o', 'd', 'y'),
#  ('y', 'o', 'u', 'r', ' ', 'b', 'o', 'd', 'y', ' '),
#  ('o', 'u', 'r', ' ', 'b', 'o', 'd', 'y', ' ', 'b'),
#  ('u', 'r', ' ', 'b', 'o', 'd', 'y', ' ', 'b', 'u'),
#  ('r', ' ', 'b', 'o', 'd', 'y', ' ', 'b', 'u', 'r'),
#  (' ', 'b', 'o', 'd', 'y', ' ', 'b', 'u', 'r', 'n'),
#  ('b', 'o', 'd', 'y', ' ', 'b', 'u', 'r', 'n', 's'),
#  ('o', 'd', 'y', ' ', 'b', 'u', 'r', 'n', 's', ' '),
#  ('d', 'y', ' ', 'b', 'u', 'r', 'n', 's', ' ', 't'),
#  ('y', ' ', 'b', 'u', 'r', 'n', 's', ' ', 't', 'h'),
#  (' ', 'b', 'u', 'r', 'n', 's', ' ', 't', 'h', 'o'),
#  ('b', 'u', 'r', 'n', 's', ' ', 't', 'h', 'o', 'u'),
#  ('u', 'r', 'n', 's', ' ', 't', 'h', 'o', 'u', 's'),
#  ('r', 'n', 's', ' ', 't', 'h', 'o', 'u', 's', 'a'),
#  ('n', 's', ' ', 't', 'h', 'o', 'u', 's', 'a', 'n'),
#  ('s', ' ', 't', 'h', 'o', 'u', 's', 'a', 'n', 'd'),
#  (' ', 't', 'h', 'o', 'u', 's', 'a', 'n', 'd', 's'),
#  ('t', 'h', 'o', 'u', 's', 'a', 'n', 'd', 's', ' '),
#  ('h', 'o', 'u', 's', 'a', 'n', 'd', 's', ' ', 'o'),
#  ('o', 'u', 's', 'a', 'n', 'd', 's', ' ', 'o', 'f'),
#  ('u', 's', 'a', 'n', 'd', 's', ' ', 'o', 'f', ' '),
#  ('s', 'a', 'n', 'd', 's', ' ', 'o', 'f', ' ', 'c'),
#  ('a', 'n', 'd', 's', ' ', 'o', 'f', ' ', 'c', 'a'),
#  ('n', 'd', 's', ' ', 'o', 'f', ' ', 'c', 'a', 'l'),
#  ('d', 's', ' ', 'o', 'f', ' ', 'c', 'a', 'l', 'o'),
#  ('s', ' ', 'o', 'f', ' ', 'c', 'a', 'l', 'o', 'r'),
#  (' ', 'o', 'f', ' ', 'c', 'a', 'l', 'o', 'r', 'i'),
#  ('o', 'f', ' ', 'c', 'a', 'l', 'o', 'r', 'i', 'e'),
#  ('f', ' ', 'c', 'a', 'l', 'o', 'r', 'i', 'e', 's'),
#  (' ', 'c', 'a', 'l', 'o', 'r', 'i', 'e', 's', ' '),
#  ('c', 'a', 'l', 'o', 'r', 'i', 'e', 's', ' ', 'i'),
#  ('a', 'l', 'o', 'r', 'i', 'e', 's', ' ', 'i', 'n'),
#  ('l', 'o', 'r', 'i', 'e', 's', ' ', 'i', 'n', ' '),
#  ('o', 'r', 'i', 'e', 's', ' ', 'i', 'n', ' ', 'o'),
#  ('r', 'i', 'e', 's', ' ', 'i', 'n', ' ', 'o', 'n'),
#  ('i', 'e', 's', ' ', 'i', 'n', ' ', 'o', 'n', 'e'),
#  ('e', 's', ' ', 'i', 'n', ' ', 'o', 'n', 'e', ' '),
#  ('s', ' ', 'i', 'n', ' ', 'o', 'n', 'e', ' ', 'd'),
#  (' ', 'i', 'n', ' ', 'o', 'n', 'e', ' ', 'd', 'a'),
#  ('i', 'n', ' ', 'o', 'n', 'e', ' ', 'd', 'a', 'y'),
#  ('n', ' ', 'o', 'n', 'e', ' ', 'd', 'a', 'y', '.'),
#  (' ', 'o', 'n', 'e', ' ', 'd', 'a', 'y', '.', '\n'),
#  ('o', 'n', 'e', ' ', 'd', 'a', 'y', '.', '\n', 'i'),
#  ('n', 'e', ' ', 'd', 'a', 'y', '.', '\n', 'i', 'f'),
#  ('e', ' ', 'd', 'a', 'y', '.', '\n', 'i', 'f', ' '),
#  (' ', 'd', 'a', 'y', '.', '\n', 'i', 'f', ' ', 'y'),
#  ('d', 'a', 'y', '.', '\n', 'i', 'f', ' ', 'y', 'o'),
#  ('a', 'y', '.', '\n', 'i', 'f', ' ', 'y', 'o', 'u'),
#  ('y', '.', '\n', 'i', 'f', ' ', 'y', 'o', 'u', ' '),
#  ('.', '\n', 'i', 'f', ' ', 'y', 'o', 'u', ' ', 'a'),
#  ('\n', 'i', 'f', ' ', 'y', 'o', 'u', ' ', 'a', 'r'),
#  ('i', 'f', ' ', 'y', 'o', 'u', ' ', 'a', 'r', 'e'),
#  ('f', ' ', 'y', 'o', 'u', ' ', 'a', 'r', 'e', ' '),
#  (' ', 'y', 'o', 'u', ' ', 'a', 'r', 'e', ' ', 'g'),
#  ('y', 'o', 'u', ' ', 'a', 'r', 'e', ' ', 'g', 'e'),
#  ('o', 'u', ' ', 'a', 'r', 'e', ' ', 'g', 'e', 't'),
#  ('u', ' ', 'a', 'r', 'e', ' ', 'g', 'e', 't', 't'),
#  (' ', 'a', 'r', 'e', ' ', 'g', 'e', 't', 't', 'i'),
#  ('a', 'r', 'e', ' ', 'g', 'e', 't', 't', 'i', 'n'),
#  ('r', 'e', ' ', 'g', 'e', 't', 't', 'i', 'n', 'g'),
#  ('e', ' ', 'g', 'e', 't', 't', 'i', 'n', 'g', ' '),
#  (' ', 'g', 'e', 't', 't', 'i', 'n', 'g', ' ', 'm'),
#  ('g', 'e', 't', 't', 'i', 'n', 'g', ' ', 'm', 'o'),
#  ('e', 't', 't', 'i', 'n', 'g', ' ', 'm', 'o', 'r'),
#  ('t', 't', 'i', 'n', 'g', ' ', 'm', 'o', 'r', 'e'),
#  ('t', 'i', 'n', 'g', ' ', 'm', 'o', 'r', 'e', ' '),
#  ('i', 'n', 'g', ' ', 'm', 'o', 'r', 'e', ' ', 'c'),
#  ('n', 'g', ' ', 'm', 'o', 'r', 'e', ' ', 'c', 'a'),
#  ('g', ' ', 'm', 'o', 'r', 'e', ' ', 'c', 'a', 'l'),
#  (' ', 'm', 'o', 'r', 'e', ' ', 'c', 'a', 'l', 'o'),
#  ('m', 'o', 'r', 'e', ' ', 'c', 'a', 'l', 'o', 'r'),
#  ('o', 'r', 'e', ' ', 'c', 'a', 'l', 'o', 'r', 'i'),
#  ('r', 'e', ' ', 'c', 'a', 'l', 'o', 'r', 'i', 'e'),
#  ('e', ' ', 'c', 'a', 'l', 'o', 'r', 'i', 'e', 's'),
#  (' ', 'c', 'a', 'l', 'o', 'r', 'i', 'e', 's', ' '),
#  ('c', 'a', 'l', 'o', 'r', 'i', 'e', 's', ' ', 't'),
#  ('a', 'l', 'o', 'r', 'i', 'e', 's', ' ', 't', 'h'),
#  ('l', 'o', 'r', 'i', 'e', 's', ' ', 't', 'h', 'a'),
#  ('o', 'r', 'i', 'e', 's', ' ', 't', 'h', 'a', 'n'),
#  ('r', 'i', 'e', 's', ' ', 't', 'h', 'a', 'n', ' '),
#  ('i', 'e', 's', ' ', 't', 'h', 'a', 'n', ' ', 'n'),
#  ('e', 's', ' ', 't', 'h', 'a', 'n', ' ', 'n', 'e'),
#  ('s', ' ', 't', 'h', 'a', 'n', ' ', 'n', 'e', 'e'),
#  (' ', 't', 'h', 'a', 'n', ' ', 'n', 'e', 'e', 'd'),
#  ('t', 'h', 'a', 'n', ' ', 'n', 'e', 'e', 'd', 'e'),
#  ('h', 'a', 'n', ' ', 'n', 'e', 'e', 'd', 'e', 'd'),
#  ('a', 'n', ' ', 'n', 'e', 'e', 'd', 'e', 'd', ','),
#  ('n', ' ', 'n', 'e', 'e', 'd', 'e', 'd', ',', ' '),
#  (' ', 'n', 'e', 'e', 'd', 'e', 'd', ',', ' ', 'y'),
#  ('n', 'e', 'e', 'd', 'e', 'd', ',', ' ', 'y', 'o'),
#  ('e', 'e', 'd', 'e', 'd', ',', ' ', 'y', 'o', 'u'),
#  ('e', 'd', 'e', 'd', ',', ' ', 'y', 'o', 'u', ' '),
#  ('d', 'e', 'd', ',', ' ', 'y', 'o', 'u', ' ', 'w'),
#  ('e', 'd', ',', ' ', 'y', 'o', 'u', ' ', 'w', 'i'),
#  ('d', ',', ' ', 'y', 'o', 'u', ' ', 'w', 'i', 'l'),
#  (',', ' ', 'y', 'o', 'u', ' ', 'w', 'i', 'l', 'l'),
#  (' ', 'y', 'o', 'u', ' ', 'w', 'i', 'l', 'l', ' '),
#  ('y', 'o', 'u', ' ', 'w', 'i', 'l', 'l', ' ', 'g'),
#  ('o', 'u', ' ', 'w', 'i', 'l', 'l', ' ', 'g', 'a'),
#  ('u', ' ', 'w', 'i', 'l', 'l', ' ', 'g', 'a', 'i'),
#  (' ', 'w', 'i', 'l', 'l', ' ', 'g', 'a', 'i', 'n'),
#  ('w', 'i', 'l', 'l', ' ', 'g', 'a', 'i', 'n', ' '),
#  ('i', 'l', 'l', ' ', 'g', 'a', 'i', 'n', ' ', 'w'),
#  ('l', 'l', ' ', 'g', 'a', 'i', 'n', ' ', 'w', 'e'),
#  ('l', ' ', 'g', 'a', 'i', 'n', ' ', 'w', 'e', 'i'),
#  (' ', 'g', 'a', 'i', 'n', ' ', 'w', 'e', 'i', 'g'),
#  ('g', 'a', 'i', 'n', ' ', 'w', 'e', 'i', 'g', 'h'),
#  ('a', 'i', 'n', ' ', 'w', 'e', 'i', 'g', 'h', 't'),
#  ('i', 'n', ' ', 'w', 'e', 'i', 'g', 'h', 't', '.'),
#  ('n', ' ', 'w', 'e', 'i', 'g', 'h', 't', '.', ' '),
#  (' ', 'w', 'e', 'i', 'g', 'h', 't', '.', ' ', 'i'),
#  ('w', 'e', 'i', 'g', 'h', 't', '.', ' ', 'i', 'f'),
#  ('e', 'i', 'g', 'h', 't', '.', ' ', 'i', 'f', ' '),
#  ('i', 'g', 'h', 't', '.', ' ', 'i', 'f', ' ', 'y'),
#  ('g', 'h', 't', '.', ' ', 'i', 'f', ' ', 'y', 'o'),
#  ('h', 't', '.', ' ', 'i', 'f', ' ', 'y', 'o', 'u'),
#  ('t', '.', ' ', 'i', 'f', ' ', 'y', 'o', 'u', ' '),
#  ('.', ' ', 'i', 'f', ' ', 'y', 'o', 'u', ' ', 'a'),
#  (' ', 'i', 'f', ' ', 'y', 'o', 'u', ' ', 'a', 'r'),
#  ('i', 'f', ' ', 'y', 'o', 'u', ' ', 'a', 'r', 'e'),
#  ('f', ' ', 'y', 'o', 'u', ' ', 'a', 'r', 'e', ' '),
#  (' ', 'y', 'o', 'u', ' ', 'a', 'r', 'e', ' ', 'g'),
#  ('y', 'o', 'u', ' ', 'a', 'r', 'e', ' ', 'g', 'e'),
#  ('o', 'u', ' ', 'a', 'r', 'e', ' ', 'g', 'e', 't'),
#  ('u', ' ', 'a', 'r', 'e', ' ', 'g', 'e', 't', 't'),
#  (' ', 'a', 'r', 'e', ' ', 'g', 'e', 't', 't', 'i'),
#  ('a', 'r', 'e', ' ', 'g', 'e', 't', 't', 'i', 'n'),
#  ('r', 'e', ' ', 'g', 'e', 't', 't', 'i', 'n', 'g'),
#  ('e', ' ', 'g', 'e', 't', 't', 'i', 'n', 'g', ' '),
#  (' ', 'g', 'e', 't', 't', 'i', 'n', 'g', ' ', 'f'),
#  ('g', 'e', 't', 't', 'i', 'n', 'g', ' ', 'f', 'e'),
#  ('e', 't', 't', 'i', 'n', 'g', ' ', 'f', 'e', 'w'),
#  ('t', 't', 'i', 'n', 'g', ' ', 'f', 'e', 'w', 'e'),
#  ('t', 'i', 'n', 'g', ' ', 'f', 'e', 'w', 'e', 'r'),
#  ('i', 'n', 'g', ' ', 'f', 'e', 'w', 'e', 'r', ' '),
#  ('n', 'g', ' ', 'f', 'e', 'w', 'e', 'r', ' ', 'c'),
#  ('g', ' ', 'f', 'e', 'w', 'e', 'r', ' ', 'c', 'a'),
#  (' ', 'f', 'e', 'w', 'e', 'r', ' ', 'c', 'a', 'l'),
#  ('f', 'e', 'w', 'e', 'r', ' ', 'c', 'a', 'l', 'o'),
#  ('e', 'w', 'e', 'r', ' ', 'c', 'a', 'l', 'o', 'r'),
#  ('w', 'e', 'r', ' ', 'c', 'a', 'l', 'o', 'r', 'i'),
#  ('e', 'r', ' ', 'c', 'a', 'l', 'o', 'r', 'i', 'e'),
#  ('r', ' ', 'c', 'a', 'l', 'o', 'r', 'i', 'e', 's'),
#  (' ', 'c', 'a', 'l', 'o', 'r', 'i', 'e', 's', ' '),
#  ('c', 'a', 'l', 'o', 'r', 'i', 'e', 's', ' ', 't'),
#  ('a', 'l', 'o', 'r', 'i', 'e', 's', ' ',
#  ('w', ' ', 'h', 'o', 'w', ' ', 'm', 'u', 'c', 'h'),
#  (' ', 'h', 'o', 'w', ' ', 'm', 'u', 'c', 'h', ' '),
#  ('h', 'o', 'w', ' ', 'm', 'u', 'c', 'h', ' ', 'c'),
#  ('o', 'w', ' ', 'm', 'u', 'c', 'h', ' ', 'c', 'a'),
#  ('w', ' ', 'm', 'u', 'c', 'h', ' ', 'c', 'a', 'l'),
#  (' ', 'm', 'u', 'c', 'h', ' ', 'c', 'a', 'l', 'o'),
#  ('m', 'u', 'c', 'h', ' ', 'c', 'a', 'l', 'o', 'r'),
#  ('u', 'c', 'h', ' ', 'c', 'a', 'l', 'o', 'r', 'i'),
#  ('c', 'h', ' ', 'c', 'a', 'l', 'o', 'r', 'i', 'e'),
#  ('h', ' ', 'c', 'a', 'l', 'o', 'r', 'i', 'e', ' '),
#  (' ', 'c', 'a', 'l', 'o', 'r', 'i', 'e', ' ', 'y'),
#  ('c', 'a', 'l', 'o', 'r', 'i', 'e', ' ', 'y', 'o'),
#  ('a', 'l', 'o', 'r', 'i', 'e', ' ', 'y', 'o', 'u'),
#  ('l', 'o', 'r', 'i', 'e', ' ', 'y', 'o', 'u', 'r'),
#  ('o', 'r', 'i', 'e', ' ', 'y', 'o', 'u', 'r', ' '),
#  ('r', 'i', 'e', ' ', 'y', 'o', 'u', 'r', ' ', 'b'),
#  ('i', 'e', ' ', 'y', 'o', 'u', 'r', ' ', 'b', 'o'),
#  ('e', ' ', 'y', 'o', 'u', 'r', ' ', 'b', 'o', 'd'),
#  (' ', 'y', 'o', 'u', 'r', ' ', 'b', 'o', 'd', 'y'),
#  ('y', 'o', 'u', 'r', ' ', 'b', 'o', 'd', 'y', ' '),
#  ('o', 'u', 'r', ' ', 'b', 'o', 'd', 'y', ' ', 'r'),
#  ('u', 'r', ' ', 'b', 'o', 'd', 'y', ' ', 'r', 'e'),
#  ('r', ' ', 'b', 'o', 'd', 'y', ' ', 'r', 'e', 'q'),
#  (' ', 'b', 'o', 'd', 'y', ' ', 'r', 'e', 'q', 'u'),
#  ('b', 'o', 'd', 'y', ' ', 'r', 'e', 'q', 'u', 'i'),
#  ('o', 'd', 'y', ' ', 'r', 'e', 'q', 'u', 'i', 'r'),
#  ('d', 'y', ' ', 'r', 'e', 'q', 'u', 'i', 'r', 'e'),
#  ('y', ' ', 'r', 'e', 'q', 'u', 'i', 'r', 'e', 'd'),
#  (' ', 'r', 'e', 'q', 'u', 'i', 'r', 'e', 'd', '.'),
#  ('r', 'e', 'q', 'u', 'i', 'r', 'e', 'd', '.', '\n'),
#  ('e', 'q', 'u', 'i', 'r', 'e', 'd', '.', '\n', 'f'),
#  ('q', 'u', 'i', 'r', 'e', 'd', '.', '\n', 'f', 'i'),
#  ('u', 'i', 'r', 'e', 'd', '.', '\n', 'f', 'i', 'n'),
#  ('i', 'r', 'e', 'd', '.', '\n', 'f', 'i', 'n', 'd'),
#  ('r', 'e', 'd', '.', '\n', 'f', 'i', 'n', 'd', ' '),
#  ('e', 'd', '.', '\n', 'f', 'i', 'n', 'd', ' ', 'r'),
#  ('d', '.', '\n', 'f', 'i', 'n', 'd', ' ', 'r', 'e'),
#  ('.', '\n', 'f', 'i', 'n', 'd', ' ', 'r', 'e', 'q'),
#  ('\n', 'f', 'i', 'n', 'd', ' ', 'r', 'e', 'q', 'u'),
#  ('f', 'i', 'n', 'd', ' ', 'r', 'e', 'q', 'u', 'i'),
#  ('i', 'n', 'd', ' ', 'r', 'e', 'q', 'u', 'i', 'r'),
#  ('n', 'd', ' ', 'r', 'e', 'q', 'u', 'i', 'r', 'e'),
#  ('d', ' ', 'r', 'e', 'q', 'u', 'i', 'r', 'e', ' '),
#  (' ', 'r', 'e', 'q', 'u', 'i', 'r', 'e', ' ', 'c'),
#  ('r', 'e', 'q', 'u', 'i', 'r', 'e', ' ', 'c', 'a'),
#  ('e', 'q', 'u', 'i', 'r', 'e', ' ', 'c', 'a', 'l'),
#  ('q', 'u', 'i', 'r', 'e', ' ', 'c', 'a', 'l', 'o'),
#  ('u', 'i', 'r', 'e', ' ', 'c', 'a', 'l', 'o', 'r'),
#  ('i', 'r', 'e', ' ', 'c', 'a', 'l', 'o', 'r', 'i'),
#  ('r', 'e', ' ', 'c', 'a', 'l', 'o', 'r', 'i', 'e'),
#  ('e', ' ', 'c', 'a', 'l', 'o', 'r', 'i', 'e', 's'),
#  (' ', 'c', 'a', 'l', 'o', 'r', 'i', 'e', 's', ' '),
#  ('c', 'a', 'l', 'o', 'r', 'i', 'e', 's', ' ', 'f'),
#  ('a', 'l', 'o', 'r', 'i', 'e', 's', ' ', 'f', 'o'),
#  ('l', 'o', 'r', 'i', 'e', 's', ' ', 'f', 'o', 'r'),
#  ('o', 'r', 'i', 'e', 's', ' ', 'f', 'o', 'r', ' '),
#  ('r', 'i', 'e', 's', ' ', 'f', 'o', 'r', ' ', 'y'),
#  ('i', 'e', 's', ' ', 'f', 'o', 'r', ' ', 'y', 'o'),
#  ('e', 's', ' ', 'f', 'o', 'r', ' ', 'y', 'o', 'u'),
#  ('s', ' ', 'f', 'o', 'r', ' ', 'y', 'o', 'u', 'r'),
#  (' ', 'f', 'o', 'r', ' ', 'y', 'o', 'u', 'r', ' '),
#  ('f', 'o', 'r', ' ', 'y', 'o', 'u', 'r', ' ', 'b'),
#  ('o', 'r', ' ', 'y', 'o', 'u', 'r', ' ', 'b', 'o'),
#  ('r', ' ', 'y', 'o', 'u', 'r', ' ', 'b', 'o', 'd'),
#  (' ', 'y', 'o', 'u', 'r', ' ', 'b', 'o', 'd', 'y'),
#  ('y', 'o', 'u', 'r', ' ', 'b', 'o', 'd', 'y', '\n'),
#  ('o', 'u', 'r', ' ', 'b', 'o', 'd', 'y', '\n', 'h'),
#  ('u', 'r', ' ', 'b', 'o', 'd', 'y', '\n', 'h', 'o'),
#  ('r', ' ', 'b', 'o', 'd', 'y', '\n', 'h', 'o', 'w'),
#  ...]

# %%
def set_of_chars_in(sequences):
    return {sublst for lst in sequences for sublst in lst}


def create_char2idx(sequences):
    set_of_chars = set_of_chars_in(sequences)
    return {char: idx for idx, char in enumerate(sorted(set_of_chars))}


def encode_sequence(sequence, char2idx):
    return [char2idx[char] for char in sequence]


def encode_sequences(sequences, char2idx):
    return np.array([
        encode_sequence(sequence, char2idx) 
        for sequence in tqdm(sequences)
    ])


class Sequences(Dataset):
    def __init__(self, path, sequence_length=125):
        self.sequences = load_data_char(DATA_PATH, sequence_length=sequence_length)
        self.vocab_size = len(set_of_chars_in(self.sequences))
        self.char2idx = create_char2idx(self.sequences)
        self.idx2char = {idx: char for char, idx in self.char2idx.items()}
        self.encoded = encode_sequences(self.sequences, self.char2idx)
        
    def __getitem__(self, i):
        return self.encoded[i, :-1], self.encoded[i, 1:]
    
    def __len__(self):
        return len(self.encoded)

# %% [markdown]
# The Tasks 2.1 to 2.3 will help you to understand the code better.

# %% [markdown]
# **2.1** <br>
# (1 Point)
# Describe the variable `chars_windowed`. What does it contain?

# %% [markdown]
# lists of characters grouped as the number by sequence_length.

# %% [markdown]
# **2.2** <br>
# (1 Point)
# Describe the variable `all_chars_windowed`. What does it contain?

# %% [markdown]
# Sublists of the lists of chars_windowed

# %% [markdown]
# **2.3** <br>
# (1 Point)
# Explain shortly, what the function `remove_unprintable_chars(all_chars_windowed)`does. We do not want a step by step explaination, just describe the generall idea.

# %% [markdown]
# Your Answer Here

# %% [markdown]
# Now lets load our char_dataset.

# %%
sequence_length=int(input("choose your sequence_length (for this task, we did choose 128): "))
if sequence_length<=1:
  print("1 or less is not a valid sequence length. Your model will not learn anything from just one word at a time. The sequence lenght of 128 has been chosen for you.")
  sequence_length=128
# Out:
# choose your sequence_length (for this task, we did choose 128): 125

# %%
dataset_char = Sequences(DATA_PATH, sequence_length=128)
len(dataset_char)
train_loader_char = DataLoader(dataset_char, batch_size=4096)
# Out:
# texts: weight gaining is a common problem around the world. in developed country, it is the most common problem. in this article, i am not going to show you some advance and magical technique which will make you slim overnight. i am going to show you tips on the basis of real facts which works. in this article, i will give you how to tips, which will help you to lose weight. are you ready?
# calories requirement
# first thing you need to understand is why you gain weight. why? whenever you eat or drink something, you will get some calories. when you think about weight, everything revolves around calories.
# whatever you do, will burn some calories no matter how small work it is or just a movement of your body. your body burns thousands of calories in one day.
# if you are getting more calories than needed, you will gain weight. if you are getting fewer calories than needed, you will lose weight. so for losing weight, you need to know how much calorie your body required.
# find require calories for your body
# how will you know that how much calories your body require? well, there is a formula to find out that but you don't need to understand that. just go tohttp://www.freedieting.com/tools/calorie_calculator.htm. enter the details and you will come to know how much calories require for your body.
# now you know how much calories your body needs. you just need to balance between require and burning calories. there are two ways you can lose weight.
# you are not going to use only one. you will use mix of both. you will consume less calories and burn more calories. so keep a track of how much calories you take. also do some more exercise. not too much just a little more. so you burn more calories.
# you are controlling calories in two ways. losing little more calories and getting little less calories. so you will definitely lose weight.
# take less calories
# burn more calories
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# HBox(children=(FloatProgress(value=0.0, max=1246263.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1228546.0), HTML(value='')))

# %% [markdown]
# <h2>3. Preprocessing the data for word-level generation</h2>

# %% [markdown]
# We now have to do the same preprocessing steps for our word-level-model. But dont worry, it works quite similar to the character-level-preprocessing steps. In the following, there are a couple of tasks, that will guide you.

# %% [markdown]
# **3.1 Tokenize**<br>
# (3 Point)
# Complete the function `tokenize` which gets multiple texts and returns a list, which consists of a list of word-level-tokens for each text.

# %%
def tokenize(texts):   
    #your code here
  texts_tokens = []
  for text in texts:
    text_tokens_pre = nltk.word_tokenize(text) 
    texts_tokens.append(text_tokens_pre)
    return texts_tokens

# %% [markdown]
# **3.2 Unprintable Sequences**<br>
# (4 Points)
# Do you remember the task 2.3? Apply the same functionality, but keep in mind, that we are now working on the basis of words, not chars.
# Adapt the function from task 2.3 so that it now works with words. We still want to delete the sequences. Write your solution into the function `remove_unprintable_sequences2`.

# %%
def remove_unprintable_sequences2(all_words_windowed):
  filtered_words = []
  #Your code here
  not_printbl_words=[]
  filtered_words=[]
  for sequence in tqdm(all_words_windowed):
    for words in sequence:
      if words.isprintable:
        filtered_words+=[sequence]
      else:
        not_printbl_words+=[words]
        if printbl==True:
          filtered_words+=[sequence]

  return filtered_words

# %% [markdown]
# We now put all the functions you provided in this new function, to load our data.

# %%
def load_data_word(path, sequence_length=5):

    #Generate a list of texts from the dataset
    texts = textlist_generator(path)


    texts=tokenize(texts)

    words_windowed = [list(windowed(text, sequence_length)) for text in texts]


    all_words_windowed = [sublst for lst in words_windowed for sublst in lst]

    filtered_words = remove_unprintable_sequences2(all_words_windowed)

    return filtered_words

# %%
load_data_word(DATA_PATH)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=375.0), HTML(value='')))
# [('weight', 'gaining', 'is', 'a', 'common'),
#  ('weight', 'gaining', 'is', 'a', 'common'),
#  ('weight', 'gaining', 'is', 'a', 'common'),
#  ('weight', 'gaining', 'is', 'a', 'common'),
#  ('weight', 'gaining', 'is', 'a', 'common'),
#  ('gaining', 'is', 'a', 'common', 'problem'),
#  ('gaining', 'is', 'a', 'common', 'problem'),
#  ('gaining', 'is', 'a', 'common', 'problem'),
#  ('gaining', 'is', 'a', 'common', 'problem'),
#  ('gaining', 'is', 'a', 'common', 'problem'),
#  ('is', 'a', 'common', 'problem', 'around'),
#  ('is', 'a', 'common', 'problem', 'around'),
#  ('is', 'a', 'common', 'problem', 'around'),
#  ('is', 'a', 'common', 'problem', 'around'),
#  ('is', 'a', 'common', 'problem', 'around'),
#  ('a', 'common', 'problem', 'around', 'the'),
#  ('a', 'common', 'problem', 'around', 'the'),
#  ('a', 'common', 'problem', 'around', 'the'),
#  ('a', 'common', 'problem', 'around', 'the'),
#  ('a', 'common', 'problem', 'around', 'the'),
#  ('common', 'problem', 'around', 'the', 'world'),
#  ('common', 'problem', 'around', 'the', 'world'),
#  ('common', 'problem', 'around', 'the', 'world'),
#  ('common', 'problem', 'around', 'the', 'world'),
#  ('common', 'problem', 'around', 'the', 'world'),
#  ('problem', 'around', 'the', 'world', '.'),
#  ('problem', 'around', 'the', 'world', '.'),
#  ('problem', 'around', 'the', 'world', '.'),
#  ('problem', 'around', 'the', 'world', '.'),
#  ('problem', 'around', 'the', 'world', '.'),
#  ('around', 'the', 'world', '.', 'in'),
#  ('around', 'the', 'world', '.', 'in'),
#  ('around', 'the', 'world', '.', 'in'),
#  ('around', 'the', 'world', '.', 'in'),
#  ('around', 'the', 'world', '.', 'in'),
#  ('the', 'world', '.', 'in', 'developed'),
#  ('the', 'world', '.', 'in', 'developed'),
#  ('the', 'world', '.', 'in', 'developed'),
#  ('the', 'world', '.', 'in', 'developed'),
#  ('the', 'world', '.', 'in', 'developed'),
#  ('world', '.', 'in', 'developed', 'country'),
#  ('world', '.', 'in', 'developed', 'country'),
#  ('world', '.', 'in', 'developed', 'country'),
#  ('world', '.', 'in', 'developed', 'country'),
#  ('world', '.', 'in', 'developed', 'country'),
#  ('.', 'in', 'developed', 'country', ','),
#  ('.', 'in', 'developed', 'country', ','),
#  ('.', 'in', 'developed', 'country', ','),
#  ('.', 'in', 'developed', 'country', ','),
#  ('.', 'in', 'developed', 'country', ','),
#  ('in', 'developed', 'country', ',', 'it'),
#  ('in', 'developed', 'country', ',', 'it'),
#  ('in', 'developed', 'country', ',', 'it'),
#  ('in', 'developed', 'country', ',', 'it'),
#  ('in', 'developed', 'country', ',', 'it'),
#  ('developed', 'country', ',', 'it', 'is'),
#  ('developed', 'country', ',', 'it', 'is'),
#  ('developed', 'country', ',', 'it', 'is'),
#  ('developed', 'country', ',', 'it', 'is'),
#  ('developed', 'country', ',', 'it', 'is'),
#  ('country', ',', 'it', 'is', 'the'),
#  ('country', ',', 'it', 'is', 'the'),
#  ('on', 'the', 'basis', 'of', 'real'),
#  ('the', 'basis', 'of', 'real', 'facts'),
#  ('the', 'basis', 'of', 'real', 'facts'),
#  ('the', 'basis', 'of', 'real', 'facts'),
#  ('the', 'basis', 'of', 'real', 'facts'),
#  ('the', 'basis', 'of', 'real', 'facts'),
#  ('basis', 'of', 'real', 'facts', 'which'),
#  ('basis', 'of', 'real', 'facts', 'which'),
#  ('basis', 'of', 'real', 'facts', 'which'),
#  ('basis', 'of', 'real', 'facts', 'which'),
#  ('basis', 'of', 'real', 'facts', 'which'),
#  ('of', 'real', 'facts', 'which', 'works'),
#  ('of', 'real', 'facts', 'which', 'works'),
#  ('of', 'real', 'facts', 'which', 'works'),
#  ('of', 'real', 'facts', 'which', 'works'),
#  ('of', 'real', 'facts', 'which', 'works'),
#  ('real', 'facts', 'which', 'works', '.'),
#  ('real', 'facts', 'which', 'works', '.'),
#  ('real', 'facts', 'which', 'works', '.'),
#  ('real', 'facts', 'which', 'works', '.'),
#  ('real', 'facts', 'which', 'works', '.'),
#  ('facts', 'which', 'works', '.', 'in'),
#  ('facts', 'which', 'works', '.', 'in'),
#  ('facts', 'which', 'works', '.', 'in'),
#  ('facts', 'which', 'works', '.', 'in'),
#  ('facts', 'which', 'works', '.', 'in'),
#  ('which', 'works', '.', 'in', 'this'),
#  ('which', 'works', '.', 'in', 'this'),
#  ('which', 'works', '.', 'in', 'this'),
#  ('which', 'works', '.', 'in', 'this'),
#  ('which', 'works', '.', 'in', 'this'),
#  ('works', '.', 'in', 'this', 'article'),
#  ('works', '.', 'in', 'this', 'article'),
#  ('works', '.', 'in', 'this', 'article'),
#  ('works', '.', 'in', 'this', 'article'),
#  ('works', '.', 'in', 'this', 'article'),
#  ('.', 'in', 'this', 'article', ','),
#  ('.', 'in', 'this', 'article', ','),
#  ('.', 'in', 'this', 'article', ','),
#  ('.', 'in', 'this', 'article', ','),
#  ('.', 'in', 'this', 'article', ','),
#  ('in', 'this', 'article', ',', 'i'),
#  ('in', 'this', 'article', ',', 'i'),
#  ('in', 'this', 'article', ',', 'i'),
#  ('in', 'this', 'article', ',', 'i'),
#  ('in', 'this', 'article', ',', 'i'),
#  ('this', 'article', ',', 'i', 'will'),
#  ('this', 'article', ',', 'i', 'will'),
#  ('this', 'article', ',', 'i', 'will'),
#  ('this', 'article', ',', 'i', 'will'),
#  ('this', 'article', ',', 'i', 'will'),
#  ('article', ',', 'i', 'will', 'give'),
#  ('article', ',', 'i', 'will', 'give'),
#  ('article', ',', 'i', 'will', 'give'),
#  ('article', ',', 'i', 'will', 'give'),
#  ('article', ',', 'i', 'will', 'give'),
#  (',', 'i', 'will', 'give', 'you'),
#  (',', 'i', 'will', 'give', 'you'),
#  (',', 'i', 'will', 'give', 'you'),
#  (',', 'i', 'will', 'give', 'you'),
#  (',', 'i', 'will', 'give', 'you'),
#  ('i', 'will', 'give', 'you', 'how'),
#  ('i', 'will', 'give', 'you', 'how'),
#  ('i', 'will', 'give', 'you', 'how'),
#  ('i', 'will', 'give', 'you', 'how'),
#  ('i', 'will', 'give', 'you', 'how'),
#  ('will', 'give', 'you', 'how', 'to'),
#  ('will', 'give', 'you', 'how', 'to'),
#  ('will', 'give', 'you', 'how', 'to'),
#  ('will', 'give', 'you', 'how', 'to'),
#  ('will', 'give', 'you', 'how', 'to'),
#  ('give', 'you', 'how', 'to', 'tips'),
#  ('give', 'you', 'how', 'to', 'tips'),
#  ('to', 'understand', 'is', 'why', 'you'),
#  ('understand', 'is', 'why', 'you', 'gain'),
#  ('understand', 'is', 'why', 'you', 'gain'),
#  ('understand', 'is', 'why', 'you', 'gain'),
#  ('understand', 'is', 'why', 'you', 'gain'),
#  ('understand', 'is', 'why', 'you', 'gain'),
#  ('is', 'why', 'you', 'gain', 'weight'),
#  ('is', 'why', 'you', 'gain', 'weight'),
#  ('is', 'why', 'you', 'gain', 'weight'),
#  ('is', 'why', 'you', 'gain', 'weight'),
#  ('is', 'why', 'you', 'gain', 'weight'),
#  ('why', 'you', 'gain', 'weight', '.'),
#  ('why', 'you', 'gain', 'weight', '.'),
#  ('why', 'you', 'gain', 'weight', '.'),
#  ('why', 'you', 'gain', 'weight', '.'),
#  ('why', 'you', 'gain', 'weight', '.'),
#  ('you', 'gain', 'weight', '.', 'why'),
#  ('you', 'gain', 'weight', '.', 'why'),
#  ('you', 'gain', 'weight', '.', 'why'),
#  ('you', 'gain', 'weight', '.', 'why'),
#  ('you', 'gain', 'weight', '.', 'why'),
#  ('gain', 'weight', '.', 'why', '?'),
#  ('gain', 'weight', '.', 'why', '?'),
#  ('gain', 'weight', '.', 'why', '?'),
#  ('gain', 'weight', '.', 'why', '?'),
#  ('gain', 'weight', '.', 'why', '?'),
#  ('weight', '.', 'why', '?', 'whenever'),
#  ('weight', '.', 'why', '?', 'whenever'),
#  ('weight', '.', 'why', '?', 'whenever'),
#  ('weight', '.', 'why', '?', 'whenever'),
#  ('weight', '.', 'why', '?', 'whenever'),
#  ('.', 'why', '?', 'whenever', 'you'),
#  ('.', 'why', '?', 'whenever', 'you'),
#  ('.', 'why', '?', 'whenever', 'you'),
#  ('.', 'why', '?', 'whenever', 'you'),
#  ('.', 'why', '?', 'whenever', 'you'),
#  ('why', '?', 'whenever', 'you', 'eat'),
#  ('why', '?', 'whenever', 'you', 'eat'),
#  ('why', '?', 'whenever', 'you', 'eat'),
#  ('why', '?', 'whenever', 'you', 'eat'),
#  ('why', '?', 'whenever', 'you', 'eat'),
#  ('?', 'whenever', 'you', 'eat', 'or'),
#  ('?', 'whenever', 'you', 'eat', 'or'),
#  ('?', 'whenever', 'you', 'eat', 'or'),
#  ('?', 'whenever', 'you', 'eat', 'or'),
#  ('?', 'whenever', 'you', 'eat', 'or'),
#  ('whenever', 'you', 'eat', 'or', 'drink'),
#  ('whenever', 'you', 'eat', 'or', 'drink'),
#  ('whenever', 'you', 'eat', 'or', 'drink'),
#  ('whenever', 'you', 'eat', 'or', 'drink'),
#  ('whenever', 'you', 'eat', 'or', 'drink'),
#  ('you', 'eat', 'or', 'drink', 'something'),
#  ('you', 'eat', 'or', 'drink', 'something'),
#  ('you', 'eat', 'or', 'drink', 'something'),
#  ('you', 'eat', 'or', 'drink', 'something'),
#  ('you', 'eat', 'or', 'drink', 'something'),
#  ('eat', 'or', 'drink', 'something', ','),
#  ('eat', 'or', 'drink', 'something', ','),
#  ('eat', 'or', 'drink', 'something', ','),
#  ('eat', 'or', 'drink', 'something', ','),
#  ('eat', 'or', 'drink', 'something', ','),
#  ('think', 'about', 'weight', ',', 'everything'),
#  ('about', 'weight', ',', 'everything', 'revolves'),
#  ('about', 'weight', ',', 'everything', 'revolves'),
#  ('about', 'weight', ',', 'everything', 'revolves'),
#  ('about', 'weight', ',', 'everything', 'revolves'),
#  ('about', 'weight', ',', 'everything', 'revolves'),
#  ('weight', ',', 'everything', 'revolves', 'around'),
#  ('weight', ',', 'everything', 'revolves', 'around'),
#  ('weight', ',', 'everything', 'revolves', 'around'),
#  ('weight', ',', 'everything', 'revolves', 'around'),
#  ('weight', ',', 'everything', 'revolves', 'around'),
#  (',', 'everything', 'revolves', 'around', 'calories'),
#  (',', 'everything', 'revolves', 'around', 'calories'),
#  (',', 'everything', 'revolves', 'around', 'calories'),
#  (',', 'everything', 'revolves', 'around', 'calories'),
#  (',', 'everything', 'revolves', 'around', 'calories'),
#  ('everything', 'revolves', 'around', 'calories', '.'),
#  ('everything', 'revolves', 'around', 'calories', '.'),
#  ('everything', 'revolves', 'around', 'calories', '.'),
#  ('everything', 'revolves', 'around', 'calories', '.'),
#  ('everything', 'revolves', 'around', 'calories', '.'),
#  ('revolves', 'around', 'calories', '.', 'whatever'),
#  ('revolves', 'around', 'calories', '.', 'whatever'),
#  ('revolves', 'around', 'calories', '.', 'whatever'),
#  ('revolves', 'around', 'calories', '.', 'whatever'),
#  ('revolves', 'around', 'calories', '.', 'whatever'),
#  ('around', 'calories', '.', 'whatever', 'you'),
#  ('around', 'calories', '.', 'whatever', 'you'),
#  ('around', 'calories', '.', 'whatever', 'you'),
#  ('around', 'calories', '.', 'whatever', 'you'),
#  ('around', 'calories', '.', 'whatever', 'you'),
#  ('calories', '.', 'whatever', 'you', 'do'),
#  ('calories', '.', 'whatever', 'you', 'do'),
#  ('calories', '.', 'whatever', 'you', 'do'),
#  ('calories', '.', 'whatever', 'you', 'do'),
#  ('calories', '.', 'whatever', 'you', 'do'),
#  ('.', 'whatever', 'you', 'do', ','),
#  ('.', 'whatever', 'you', 'do', ','),
#  ('.', 'whatever', 'you', 'do', ','),
#  ('.', 'whatever', 'you', 'do', ','),
#  ('.', 'whatever', 'you', 'do', ','),
#  ('whatever', 'you', 'do', ',', 'will'),
#  ('whatever', 'you', 'do', ',', 'will'),
#  ('whatever', 'you', 'do', ',', 'will'),
#  ('whatever', 'you', 'do', ',', 'will'),
#  ('whatever', 'you', 'do', ',', 'will'),
#  ('you', 'do', ',', 'will', 'burn'),
#  ('you', 'do', ',', 'will', 'burn'),
#  ('you', 'do', ',', 'will', 'burn'),
#  ('you', 'do', ',', 'will', 'burn'),
#  ('you', 'do', ',', 'will', 'burn'),
#  ('do', ',', 'will', 'burn', 'some'),
#  ('do', ',', 'will', 'burn', 'some'),
#  ('do', ',', 'will', 'burn', 'some'),
#  ('do', ',', 'will', 'burn', 'some'),
#  ('do', ',', 'will', 'burn', 'some'),
#  (',', 'will', 'burn', 'some', 'calories'),
#  (',', 'will', 'burn', 'some', 'calories'),
#  (',', 'will', 'burn', 'some', 'calories'),
#  (',', 'will', 'burn', 'some', 'calories'),
#  (',', 'will', 'burn', 'some', 'calories'),
#  ('will', 'burn', 'some', 'calories', 'no'),
#  ('will', 'burn', 'some', 'calories', 'no'),
#  ('will', 'burn', 'some', 'calories', 'no'),
#  ('will', 'burn', 'some', 'calories', 'no'),
#  ('will', 'burn', 'some', 'calories', 'no'),
#  ('burn', 'some', 'calories', 'no', 'matter'),
#  ('burn', 'some', 'calories', 'no', 'matter'),
#  ('burn', 'some', 'calories', 'no', 'matter'),
#  ('burn', 'some', 'calories', 'no', 'matter'),
#  ('burn', 'some', 'calories', 'no', 'matter'),
#  ('some', 'calories', 'no', 'matter', 'how'),
#  ('some', 'calories', 'no', 'matter', 'how'),
#  ('some', 'calories', 'no', 'matter', 'how'),
#  ('some', 'calories', 'no', 'matter', 'how'),
#  ('some', 'calories', 'no', 'matter', 'how'),
#  ('calories', 'no', 'matter', 'how', 'small'),
#  ('calories', 'no', 'matter', 'how', 'small'),
#  ('calories', 'no', 'matter', 'how', 'small'),
#  ('calories', 'no', 'matter', 'how', 'small'),
#  ('calories', 'no', 'matter', 'how', 'small'),
#  ('no', 'matter', 'how', 'small', 'work'),
#  ('no', 'matter', 'how', 'small', 'work'),
#  ('no', 'matter', 'how', 'small', 'work'),
#  ('no', 'matter', 'how', 'small', 'work'),
#  ('no', 'matter', 'how', 'small', 'work'),
#  ('matter', 'how', 'small', 'work', 'it'),
#  ('matter', 'how', 'small', 'work', 'it'),
#  ('matter', 'how', 'small', 'work', 'it'),
#  ('matter', 'how', 'small', 'work', 'it'),
#  ('matter', 'how', 'small', 'work', 'it'),
#  ('how', 'small', 'work', 'it', 'is'),
#  ('how', 'small', 'work', 'it', 'is'),
#  ('how', 'small', 'work', 'it', 'is'),
#  ('how', 'small', 'work', 'it', 'is'),
#  ('how', 'small', 'work', 'it', 'is'),
#  ('small', 'work', 'it', 'is', 'or'),
#  ('small', 'work', 'it', 'is', 'or'),
#  ('small', 'work', 'it', 'is', 'or'),
#  ('small', 'work', 'it', 'is', 'or'),
#  ('small', 'work', 'it', 'is', 'or'),
#  ('work', 'it', 'is', 'or', 'just'),
#  ('work', 'it', 'is', 'or', 'just'),
#  ('work', 'it', 'is', 'or', 'just'),
#  ('work', 'it', 'is', 'or', 'just'),
#  ('work', 'it', 'is', 'or', 'just'),
#  ('it', 'is', 'or', 'just', 'a'),
#  ('it', 'is', 'or', 'just', 'a'),
#  ('it', 'is', 'or', 'just', 'a'),
#  ('it', 'is', 'or', 'just', 'a'),
#  ('it', 'is', 'or', 'just', 'a'),
#  ('is', 'or', 'just', 'a', 'movement'),
#  ('is', 'or', 'just', 'a', 'movement'),
#  ('is', 'or', 'just', 'a', 'movement'),
#  ('is', 'or', 'just', 'a', 'movement'),
#  ('is', 'or', 'just', 'a', 'movement'),
#  ('or', 'just', 'a', 'movement', 'of'),
#  ('or', 'just', 'a', 'movement', 'of'),
#  ('or', 'just', 'a', 'movement', 'of'),
#  ('or', 'just', 'a', 'movement', 'of'),
#  ('or', 'just', 'a', 'movement', 'of'),
#  ('just', 'a', 'movement', 'of', 'your'),
#  ('calories', 'in', 'one', 'day', '.'),
#  ('calories', 'in', 'one', 'day', '.'),
#  ('calories', 'in', 'one', 'day', '.'),
#  ('calories', 'in', 'one', 'day', '.'),
#  ('in', 'one', 'day', '.', 'if'),
#  ('in', 'one', 'day', '.', 'if'),
#  ('in', 'one', 'day', '.', 'if'),
#  ('in', 'one', 'day', '.', 'if'),
#  ('in', 'one', 'day', '.', 'if'),
#  ('one', 'day', '.', 'if', 'you'),
#  ('one', 'day', '.', 'if', 'you'),
#  ('one', 'day', '.', 'if', 'you'),
#  ('one', 'day', '.', 'if', 'you'),
#  ('one', 'day', '.', 'if', 'you'),
#  ('day', '.', 'if', 'you', 'are'),
#  ('day', '.', 'if', 'you', 'are'),
#  ('day', '.', 'if', 'you', 'are'),
#  ('day', '.', 'if', 'you', 'are'),
#  ('day', '.', 'if', 'you', 'are'),
#  ('.', 'if', 'you', 'are', 'getting'),
#  ('.', 'if', 'you', 'are', 'getting'),
#  ('.', 'if', 'you', 'are', 'getting'),
#  ('.', 'if', 'you', 'are', 'getting'),
#  ('.', 'if', 'you', 'are', 'getting'),
#  ('if', 'you', 'are', 'getting', 'more'),
#  ('if', 'you', 'are', 'getting', 'more'),
#  ('if', 'you', 'are', 'getting', 'more'),
#  ('if', 'you', 'are', 'getting', 'more'),
#  ('if', 'you', 'are', 'getting', 'more'),
#  ('you', 'are', 'getting', 'more', 'calories'),
#  ('you', 'are', 'getting', 'more', 'calories'),
#  ('you', 'are', 'getting', 'more', 'calories'),
#  ('you', 'are', 'getting', 'more', 'calories'),
#  ('you', 'are', 'getting', 'more', 'calories'),
#  ('are', 'getting', 'more', 'calories', 'than'),
#  ('are', 'getting', 'more', 'calories', 'than'),
#  ('are', 'getting', 'more', 'calories', 'than'),
#  ('are', 'getting', 'more', 'calories', 'than'),
#  ('are', 'getting', 'more', 'calories', 'than'),
#  ('getting', 'more', 'calories', 'than', 'needed'),
#  ('getting', 'more', 'calories', 'than', 'needed'),
#  ('getting', 'more', 'calories', 'than', 'needed'),
#  ('getting', 'more', 'calories', 'than', 'needed'),
#  ('getting', 'more', 'calories', 'than', 'needed'),
#  ('more', 'calories', 'than', 'needed', ','),
#  ('more', 'calories', 'than', 'needed', ','),
#  ('more', 'calories', 'than', 'needed', ','),
#  ('more', 'calories', 'than', 'needed', ','),
#  ('more', 'calories', 'than', 'needed', ','),
#  ('calories', 'than', 'needed', ',', 'you'),
#  ('calories', 'than', 'needed', ',', 'you'),
#  ('calories', 'than', 'needed', ',', 'you'),
#  ('calories', 'than', 'needed', ',', 'you'),
#  ('calories', 'than', 'needed', ',', 'you'),
#  ('than', 'needed', ',', 'you', 'will'),
#  ('than', 'needed', ',', 'you', 'will'),
#  ('than', 'needed', ',', 'you', 'will'),
#  ('than', 'needed', ',', 'you', 'will'),
#  ('than', 'needed', ',', 'you', 'will'),
#  ('needed', ',', 'you', 'will', 'gain'),
#  ('needed', ',', 'you', 'will', 'gain'),
#  ('needed', ',', 'you', 'will', 'gain'),
#  ('needed', ',', 'you', 'will', 'gain'),
#  ('needed', ',', 'you', 'will', 'gain'),
#  (',', 'you', 'will', 'gain', 'weight'),
#  (',', 'you', 'will', 'gain', 'weight'),
#  (',', 'you', 'will', 'gain', 'weight'),
#  (',', 'you', 'will', 'gain', 'weight'),
#  (',', 'you', 'will', 'gain', 'weight'),
#  ('you', 'will', 'gain', 'weight', '.'),
#  ('you', 'will', 'gain', 'weight', '.'),
#  ('you', 'will', 'gain', 'weight', '.'),
#  ('you', 'will', 'gain', 'weight', '.'),
#  ('you', 'will', 'gain', 'weight', '.'),
#  ('will', 'gain', 'weight', '.', 'if'),
#  ('will', 'gain', 'weight', '.', 'if'),
#  ('will', 'gain', 'weight', '.', 'if'),
#  ('will', 'gain', 'weight', '.', 'if'),
#  ('will', 'gain', 'weight', '.', 'if'),
#  ('gain', 'weight', '.', 'if', 'you'),
#  ('gain', 'weight', '.', 'if', 'you'),
#  ('gain', 'weight', '.', 'if', 'you'),
#  ('gain', 'weight', '.', 'if', 'you'),
#  ('gain', 'weight', '.', 'if', 'you'),
#  ('weight', '.', 'if', 'you', 'are'),
#  ('weight', '.', 'if', 'you', 'are'),
#  ('weight', '.', 'if', 'you', 'are'),
#  ('weight', '.', 'if', 'you', 'are'),
#  ('weight', '.', 'if', 'you', 'are'),
#  ('.', 'if', 'you', 'are', 'getting'),
#  ('.', 'if', 'you', 'are', 'getting'),
#  ('.', 'if', 'you', 'are', 'getting'),
#  ('.', 'if', 'you', 'are', 'getting'),
#  ('.', 'if', 'you', 'are', 'getting'),
#  ('if', 'you', 'are', 'getting', 'fewer'),
#  ('if', 'you', 'are', 'getting', 'fewer'),
#  ('if', 'you', 'are', 'getting', 'fewer'),
#  ('if', 'you', 'are', 'getting', 'fewer'),
#  ('if', 'you', 'are', 'getting', 'fewer'),
#  ('you', 'are', 'getting', 'fewer', 'calories'),
#  ('you', 'are', 'getting', 'fewer', 'calories'),
#  ('you', 'are', 'getting', 'fewer', 'calories'),
#  ('you', 'are', 'getting', 'fewer', 'calories'),
#  ('you', 'are', 'getting', 'fewer', 'calories'),
#  ('are', 'getting', 'fewer', 'calories', 'than'),
#  ('are', 'getting', 'fewer', 'calories', 'than'),
#  ('are', 'getting', 'fewer', 'calories', 'than'),
#  ('are', 'getting', 'fewer', 'calories', 'than'),
#  ('are', 'getting', 'fewer', 'calories', 'than'),
#  ('getting', 'fewer', 'calories', 'than', 'needed'),
#  ('getting', 'fewer', 'calories', 'than', 'needed'),
#  ('getting', 'fewer', 'calories', 'than', 'needed'),
#  ('getting', 'fewer', 'calories', 'than', 'needed'),
#  ('getting', 'fewer', 'calories', 'than', 'needed'),
#  ('fewer', 'calories', 'than', 'needed', ','),
#  ('fewer', 'calories', 'than', 'needed', ','),
#  ('fewer', 'calories', 'than', 'needed', ','),
#  ('fewer', 'calories', 'than', 'needed', ','),
#  ('fewer', 'calories', 'than', 'needed', ','),
#  ('calories', 'than', 'needed', ',', 'you'),
#  ('calories', 'than', 'needed', ',', 'you'),
#  ('calories', 'than', 'needed', ',', 'you'),
#  ('calories', 'than', 'needed', ',', 'you'),
#  ('calories', 'than', 'needed', ',', 'you'),
#  ('than', 'needed', ',', 'you', 'will'),
#  ('than', 'needed', ',', 'you', 'will'),
#  ('than', 'needed', ',', 'you', 'will'),
#  ('than', 'needed', ',', 'you', 'will'),
#  ('than', 'needed', ',', 'you', 'will'),
#  ('needed', ',', 'you', 'will', 'lose'),
#  ('needed', ',', 'you', 'will', 'lose'),
#  ('needed', ',', 'you', 'will', 'lose'),
#  ('needed', ',', 'you', 'will', 'lose'),
#  ('needed', ',', 'you', 'will', 'lose'),
#  (',', 'you', 'will', 'lose', 'weight'),
#  (',', 'you', 'will', 'lose', 'weight'),
#  (',', 'you', 'will', 'lose', 'weight'),
#  (',', 'you', 'will', 'lose', 'weight'),
#  (',', 'you', 'will', 'lose', 'weight'),
#  ('you', 'will', 'lose', 'weight', '.'),
#  ('you', 'will', 'lose', 'weight', '.'),
#  ('you', 'will', 'lose', 'weight', '.'),
#  ('you', 'will', 'lose', 'weight', '.'),
#  ('you', 'will', 'lose', 'weight', '.'),
#  ('will', 'lose', 'weight', '.', 'so'),
#  ('will', 'lose', 'weight', '.', 'so'),
#  ('will', 'lose', 'weight', '.', 'so'),
#  ('will', 'lose', 'weight', '.', 'so'),
#  ('will', 'lose', 'weight', '.', 'so'),
#  ('lose', 'weight', '.', 'so', 'for'),
#  ('how', 'much', 'calorie', 'your', 'body'),
#  ('how', 'much', 'calorie', 'your', 'body'),
#  ('much', 'calorie', 'your', 'body', 'required'),
#  ('much', 'calorie', 'your', 'body', 'required'),
#  ('much', 'calorie', 'your', 'body', 'required'),
#  ('much', 'calorie', 'your', 'body', 'required'),
#  ('much', 'calorie', 'your', 'body', 'required'),
#  ('calorie', 'your', 'body', 'required', '.'),
#  ('calorie', 'your', 'body', 'required', '.'),
#  ('calorie', 'your', 'body', 'required', '.'),
#  ('calorie', 'your', 'body', 'required', '.'),
#  ('calorie', 'your', 'body', 'required', '.'),
#  ('your', 'body', 'required', '.', 'find'),
#  ('your', 'body', 'required', '.', 'find'),
#  ('your', 'body', 'required', '.', 'find'),
#  ('your', 'body', 'required', '.', 'find'),
#  ('your', 'body', 'required', '.', 'find'),
#  ('body', 'required', '.', 'find', 'require'),
#  ('body', 'required', '.', 'find', 'require'),
#  ('body', 'required', '.', 'find', 'require'),
#  ('body', 'required', '.', 'find', 'require'),
#  ('body', 'required', '.', 'find', 'require'),
#  ('required', '.', 'find', 'require', 'calories'),
#  ('required', '.', 'find', 'require', 'calories'),
#  ('required', '.', 'find', 'require', 'calories'),
#  ('required', '.', 'find', 'require', 'calories'),
#  ('required', '.', 'find', 'require', 'calories'),
#  ...]

# %% [markdown]
# ****

# %% [markdown]
# **3.3** </br>
# (1 Points)
# Write a function that returns a set of all the words in the sequence.

# %%
def set_of_words_in(sequences):
    #Your Code here
    set_of_words = set()
    for i in range(len(sequences)):
        set_of_words.add(sequences[i])    
    return set_of_words

# %% [markdown]
# **3.4** </br>
# (1 Points)
# Write a function that returns a dictionary containing the set of words indentified in task 3.3 and assigns an index to each of them.

# %%
def create_word2idx(sequences):
    set_of_words = set_of_words_in(sequences)
    return {word: idx for idx, word in enumerate(sorted(set_of_words))}

# %% [markdown]
# **3.5** </br>
# (1 Points)
# Create a function `encode_sequence`, that transforms the words of a list of words `sequence` into their equivalent index from `word2index`.

# %%
def encode_sequence(sequence, word2idx):
    return [#YOUR CODE HERE]

# %% [markdown]
# **3.6** </br>
# (1 Points)
# Complete the function `encode_sequences` that generates a numpy array, with the encoded sequence of all the sequences.

# %%
def encode_sequences(sequences, word2idx):
    return np.array([
        #YOUR CODE HERE
    ])

# %% [markdown]
# In the next code snippet we call all the functions you defined above. (You dont have to do anything here, just run the cell)

# %%
class Sequences(Dataset):
    def __init__(self, path, sequence_length=30):
        self.sequences = load_data_word(DATA_PATH, sequence_length=sequence_length)
        self.vocab_size = len(set_of_words_in(self.sequences))
        self.word2idx = create_word2idx(self.sequences)
        self.idx2word = {idx: word for word, idx in self.word2idx.items()}
        self.encoded = encode_sequences(self.sequences, self.word2idx)
        
    def __getitem__(self, i):
        return self.encoded[i, :-1], self.encoded[i, 1:]
    
    def __len__(self):
        return len(self.encoded)

# %%
sequence_length=int(input("choose your sequence_length (for this task, we did choose 1o): "))
if sequence_length<=1:
  print("1 or less is not a valid sequence length. Your model will not learn anything from just one word at a time. The sequence lenght of 10 has been chosen for you.")
  sequence_length=10

# %%
dataset_word = Sequences(DATA_PATH, sequence_length)
len(dataset_word)
train_loader_word = DataLoader(dataset_word, batch_size=4096)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=258290.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=257741.0), HTML(value='')))

# %% [markdown]
# <h2>4. char-RNN: Character-level text generation</h2>
#
# For an Idea how it could be done read this [Blog post](http://karpathy.github.io/2015/05/21/rnn-effectiveness/). In there they are using an LSTM to generate new texts on character Level. To make it easier for you, in this notebook we are Building a RNN with GRU as basis. GRU works close to LSTM, but is easier to handle. For a full comparison of these two have a look at [this](http://www.wildml.com/2015/10/recurrent-neural-network-tutorial-part-4-implementing-a-grulstm-rnn-with-python-and-theano/)

# %%
class RNN(nn.Module):
    def __init__(
        self,
        vocab_size,
        embedding_dimension=100,
        hidden_size=128, 
        n_layers=1,
        device='cpu',
    ):
        
        super(RNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.device = device
        
        #Our Building-Blocks:
        self.encoder = nn.Embedding(vocab_size, embedding_dimension)
        self.rnn = nn.GRU(
            embedding_dimension,
            hidden_size,
            num_layers=n_layers,
            batch_first=True,
        )
        self.decoder = nn.Linear(hidden_size, vocab_size)
        
    def init_hidden(self, batch_size):
        #we initialize a random hidden state
        return torch.randn(self.n_layers, batch_size, self.hidden_size).to(self.device)
    
    def forward(self, input_, hidden):
        #we feed the input through our RNN
        encoded = self.encoder(input_)
        output, hidden = self.rnn(encoded.unsqueeze(1), hidden)
        output = self.decoder(output.squeeze(1))
        return output, hidden

# %% [markdown]
# Lets Initialize the model with the data for chars

# %%
model_char = RNN(vocab_size=dataset_char.vocab_size, device=device_char).to(device_char)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(
    filter(lambda p: p.requires_grad, model_char.parameters()),
    lr=0.001,
)

# %%
print(model_char)
print()
print('Trainable parameters:')
print('\n'.join([' * ' + x[0] for x in model_char.named_parameters() if x[1].requires_grad]))
# Out:
# RNN(
#   (encoder): Embedding(66, 100)
#   (rnn): GRU(100, 128, batch_first=True)
#   (decoder): Linear(in_features=128, out_features=66, bias=True)
# )
#
# Trainable parameters:
#  * encoder.weight
#  * rnn.weight_ih_l0
#  * rnn.weight_hh_l0
#  * rnn.bias_ih_l0
#  * rnn.bias_hh_l0
#  * decoder.weight
#  * decoder.bias

# %% [markdown]
# ![](images/char_rnn_diagram.png)

# %%
model_char.train()
train_losses = []
for epoch in range(30):
    progress_bar = tqdm(train_loader_char, leave=False)
    losses = []
    total = 0
    for inputs, targets in progress_bar:
        batch_size = inputs.size(0)
        hidden = model_char.init_hidden(batch_size)

        model_char.zero_grad()
        
        loss = 0
        for char_idx in range(inputs.size(1)):
            output, hidden = model_char(inputs[:, char_idx].to(device_char), hidden)
            loss += criterion(output, targets[:, char_idx].to(device_char))

        loss.backward()

        optimizer.step()
        
        avg_loss = loss.item() / inputs.size(1)
        
        progress_bar.set_description(f'Loss: {avg_loss:.3f}')
        
        losses.append(avg_loss)
        total += 1
    
    epoch_loss = sum(losses) / total
    train_losses.append(epoch_loss)
        
    tqdm.write(f'Epoch #{epoch + 1}\tTrain Loss: {epoch_loss:.3f}')


#Again, this will take a while. Go for a walk in the sunshine or something else nice :D
# Out:
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #1	Train Loss: 2.258
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #2	Train Loss: 1.750
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #3	Train Loss: 1.593
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #4	Train Loss: 1.508
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #5	Train Loss: 1.454
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #6	Train Loss: 1.418
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #7	Train Loss: 1.391
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #8	Train Loss: 1.371
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #9	Train Loss: 1.354
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #10	Train Loss: 1.340
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #11	Train Loss: 1.329
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #12	Train Loss: 1.319
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #13	Train Loss: 1.311
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #14	Train Loss: 1.303
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #15	Train Loss: 1.297
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #16	Train Loss: 1.291
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #17	Train Loss: 1.285
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #18	Train Loss: 1.281
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #19	Train Loss: 1.276
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #20	Train Loss: 1.272
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #21	Train Loss: 1.269
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #22	Train Loss: 1.265
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #23	Train Loss: 1.262
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #24	Train Loss: 1.259
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #25	Train Loss: 1.257
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #26	Train Loss: 1.254
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #27	Train Loss: 1.252
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #28	Train Loss: 1.249
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #29	Train Loss: 1.247
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Epoch #30	Train Loss: 1.245

# %% [markdown]
# Now lets test this:

# %%
def pretty_print(text):
    """Wrap text for nice printing."""
    to_print = ''
    for paragraph in text.split('\n'):
        to_print += '\n'.join(wrap(paragraph))
        to_print += '\n'
    print(to_print)

#this temperature defines how "strict" the RNN is following the original
temperature = 1.0

model_char.eval()
seed = '\n'
text = ''
with torch.no_grad():
    batch_size = 1
    hidden = model_char.init_hidden(batch_size)
    last_char = dataset_char.char2idx[seed]
    for _ in range(1000):
        output, hidden = model_char(torch.LongTensor([last_char]).to(device_char), hidden)
        
        #find the next char
        distribution = output.squeeze().div(temperature).exp()
        guess = torch.multinomial(distribution, 1).item()
        
        #the next char is the new last_char
        last_char = guess

        #append char to text.
        text += dataset_char.idx2char[guess]
        
pretty_print(text)
# Out:
# off your high speed decide to set a followed up the dayful frim, but
# it does. onhed reaching diet so as maximulaging, a body adit on the
# diets are a lot pills. i have me to lose weight. (body will two think
# type of scare self restonal health. as longinot system on keep your
# maring 20-6% even cas highing a tried granced strength or nutrition
# quick plant to re-leed to a gard", yourselves? by the hormones makes,
# pretty week. yet some diets don't you will thighs make you. this is
# cravola more more undertime could not get to digure the fats, you
# should you hands the day of fees a prrocest and hand anywhelicard the
# exactly..xeence a pain. oncer, routine. but have soontit to lose
# weight that maybe are, it will be renecy nument that you will make
# from when you keep mention if you products:
# sweet why most of the weekend. weight so the leth as a whole ben 100
# miles on much amount of dangly or in least breakfast on uson day"
# havorited to the fat busidly protein slays right individe up sorcises,
# w

# %% [markdown]
# Even though it may not be sentences, those words already sound like they are out of the mouth of your fitness coach. Maybe our word-level-model can do more.

# %% [markdown]
# <h2>5. Word-RNN: Word-level text generation</h2>
#
# Since the Dataset is originally made for char-level-generation this of course is probably not appropriate for word-level-generator. Just as a prove of concept, we will still show you how it works. The results are still quite good.

# %%
model_word = RNN(vocab_size=dataset_word.vocab_size, device=device_word).to(device_word)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(
    filter(lambda p: p.requires_grad, model_word.parameters()),
    lr=0.001,
)

# %%
print(model_word)
print()
print('Trainable parameters:')
print('\n'.join([' * ' + x[0] for x in model_word.named_parameters() if x[1].requires_grad]))
# Out:
# RNN(
#   (encoder): Embedding(10595, 100)
#   (rnn): GRU(100, 128, batch_first=True)
#   (decoder): Linear(in_features=128, out_features=10595, bias=True)
# )
#
# Trainable parameters:
#  * encoder.weight
#  * rnn.weight_ih_l0
#  * rnn.weight_hh_l0
#  * rnn.bias_ih_l0
#  * rnn.bias_hh_l0
#  * decoder.weight
#  * decoder.bias

# %% [markdown]
# ![](images/char_rnn_diagram.png)

# %% [markdown]
# **5.1**
# <br>
# (4 Points)
# Now that you have seen, how our character-level model is trained, it is time to do the same for our word-level-model.
# Now it is your turn to implement the loss function. Have a look at the code from char-level-generation as an orientation.

# %%
model_word.train()
train_losses = []
for epoch in range(50):
    progress_bar = tqdm(train_loader_word, leave=False)
    losses = []
    total = 0
    for inputs, targets in progress_bar:
        batch_size = inputs.size(0)
        hidden = model_word.init_hidden(batch_size)

        model_word.zero_grad()
        
        loss = 0
        #Your Code here

        loss.backward()

        optimizer.step()
        
        avg_loss = loss.item() / inputs.size(1)
        
        progress_bar.set_description(f'Loss: {avg_loss:.3f}')
        
        losses.append(avg_loss)
        total += 1
    
    epoch_loss = sum(losses) / total
    train_losses.append(epoch_loss)
        
    tqdm.write(f'Epoch #{epoch + 1}\tTrain Loss: {epoch_loss:.3f}')

# %% [markdown]
# Big finale: Now we want you to test your model: Try it out and look if it works.

# %%
def pretty_print(text):
    """Wrap text for nice printing."""
    to_print = ''
    for paragraph in text.split('\n'):
        to_print += '\n'.join(wrap(paragraph))
        to_print += '\n'
    print(to_print)



def generate(keywords, model_word):


  keywords=keywords.lower()
  text_tokens=[]
  #for every sentence.,.
  texts_sent=sent_tokenize(keywords)
  for sent in texts_sent:
    #we seperate the sentece into words...
    sent=word_tokenize(sent)
    #...and add these words into this list
    for token in sent:
      text_tokens+=[token+" "]
  #our seed is only the last word of your input
  seed=text_tokens[-1]
  
  #check if your word is even in the training-data
  try:
    dataset_word.word2idx[seed]
  except KeyError:
    print("the Word",seed,"is not part of the learned words and therefore can not be used as starting point for the new text")

  temperature = 1.0 

  model_word.eval()
  text = ""
  with torch.no_grad():
      batch_size = 1
      hidden = model_word.init_hidden(batch_size)
      last_word = dataset_word.word2idx[seed]
      for _ in range(100):
          output, hidden = model_word(torch.LongTensor([last_word]).to(device_word), hidden)
          
          distribution = output.squeeze().div(temperature).exp()
          guess = torch.multinomial(distribution, 1).item()
          
          last_word = guess
          text += dataset_word.idx2word[guess]
  return text     


keywords=input("Start your text about fitness with a few words: ")

text=generate(keywords, model_word)
pretty_print(text)
# Out:
# Start your text about fitness with a few words: you
# will not conquer which are actually straight to satisfy the creation
# of navarra products should also celebrations is made from being bad
# reading to the gym with other snack thin as cinnamon men and those
# types of what you have put as much this procedure though you should be
# easy , or less they want to grow and fats are knowledgeable of the
# brain that more importantly - if they do n't have the faith of weight
# loss becomes fewer calories is . it is a very careful ! el331014
# mistaken ( the metabolism may be sabotaging an stricter affected

# %% [markdown]
# Now you can look at the resuls of your Char-Level and Word-Level-Model. This of course is not graded, but might be interesting for you.

# %% [markdown]
# Congratulation! You are done now
